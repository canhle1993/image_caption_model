# %% [markdown]
# ## 0. Kiem tra moi truong va kernel
#
# Cell nay kiem tra Python interpreter, kernel Jupyter, virtualenv/conda, va xac nhan ban dang mo notebook bang moi truong phu hop.

# %%
# Thiết lập thư mục làm việc local và chẩn đoán môi trường trong VS Code / Jupyter
from pathlib import Path
import os
import platform
import subprocess
import sys

NOTEBOOK_FILENAME = 'ImageCaptioning_Flickr8k_VGG16_Keras.ipynb'

def find_project_root(start_path: Path) -> Path:
    """Tìm thư mục project gốc ngay cả khi cwd đang ở trong workspace/."""
    current = start_path.resolve()
    for candidate in [current, *current.parents]:
        if (candidate / NOTEBOOK_FILENAME).exists():
            return candidate
    return start_path.resolve()

PROJECT_ROOT = find_project_root(Path.cwd())
os.chdir(PROJECT_ROOT)
WORK_DIR = PROJECT_ROOT / 'workspace'
WORK_DIR.mkdir(parents=True, exist_ok=True)

EXPECTED_KERNEL_NAME = 'tf-metal'
EXPECTED_CONDA_ENV = 'tf-metal'
venv_path = os.environ.get('VIRTUAL_ENV')
conda_prefix = os.environ.get('CONDA_PREFIX')
conda_env_name = os.environ.get('CONDA_DEFAULT_ENV')
IS_MACOS = platform.system() == 'Darwin'
IS_APPLE_SILICON = IS_MACOS and platform.machine() == 'arm64'
ipykernel_launcher = 'ipykernel_launcher' in ' '.join(sys.argv)
kernel_connection_file = Path(os.environ.get('JPY_CONNECTION_FILE', '')).name if os.environ.get('JPY_CONNECTION_FILE') else 'Không rõ'
looks_like_system_python = sys.prefix == getattr(sys, 'base_prefix', sys.prefix) and not venv_path and not conda_prefix
using_expected_tf_metal_env = EXPECTED_CONDA_ENV in sys.executable or conda_env_name == EXPECTED_CONDA_ENV or (conda_prefix and conda_prefix.endswith(f'/{EXPECTED_CONDA_ENV}'))

apple_gpu_summary = 'Không xác định'
if IS_MACOS:
    try:
        sp_output = subprocess.check_output(['system_profiler', 'SPDisplaysDataType'], text=True)
        if 'Apple M' in sp_output or 'Metal: Supported' in sp_output:
            apple_gpu_summary = 'Phát hiện Apple GPU với Metal support'
        else:
            apple_gpu_summary = 'Không thấy thông tin Apple GPU rõ ràng'
    except Exception:
        apple_gpu_summary = 'Không đọc được system_profiler'

print('=== Môi trường chạy notebook ===')
print(f'Project root: {PROJECT_ROOT}')
print(f'WORK_DIR: {WORK_DIR}')
print(f'Python executable: {sys.executable}')
print(f'Python version: {platform.python_version()}')
print(f'sys.prefix: {sys.prefix}')
print(f'Đang chạy qua ipykernel: {ipykernel_launcher}')
print(f'Kernel connection file: {kernel_connection_file}')
print(f'VIRTUAL_ENV: {venv_path or "Không có"}')
print(f'CONDA_PREFIX: {conda_prefix or "Không có"}')
print(f'CONDA_DEFAULT_ENV: {conda_env_name or "Không có"}')
print(f'Kernel mong muốn: {EXPECTED_KERNEL_NAME}')
print(f'Apple Silicon: {IS_APPLE_SILICON}')
print(f'Trạng thái GPU trên macOS: {apple_gpu_summary}')

if conda_prefix or venv_path:
    print('Kernel hiện tại có vẻ đang dùng môi trường ảo, phù hợp để chạy notebook.')
elif looks_like_system_python:
    print('Cảnh báo: notebook có vẻ đang chạy bằng Python hệ thống.')
    print('Nếu bạn đã tạo venv/conda riêng cho dự án, hãy đổi kernel trong VS Code để tránh lỗi package.')

if using_expected_tf_metal_env:
    print(f'Đang dùng đúng môi trường mong muốn: {EXPECTED_CONDA_ENV}')
else:
    print(f'CẢNH BÁO: Bạn đang không ở đúng môi trường {EXPECTED_CONDA_ENV}. TensorFlow có thể sẽ chạy CPU hoặc thiếu package.')
    print('Trong VS Code: bấm vào tên kernel góc trên bên phải và chọn đúng kernel tf-metal.')
# Out:
# === Môi trường chạy notebook ===
# Project root: /Applications/Python_AI/Neural_Image_Caption_Generation
# WORK_DIR: /Applications/Python_AI/Neural_Image_Caption_Generation/workspace
# Python executable: /opt/anaconda3/envs/tf-metal/bin/python
# Python version: 3.10.20
# sys.prefix: /opt/anaconda3/envs/tf-metal
# Đang chạy qua ipykernel: True
# Kernel connection file: Không rõ
# VIRTUAL_ENV: Không có
# CONDA_PREFIX: /opt/anaconda3/envs/tf-metal
# CONDA_DEFAULT_ENV: tf-metal
# Kernel mong muốn: tf-metal
# Apple Silicon: True
# Trạng thái GPU trên macOS: Phát hiện Apple GPU với Metal support
# Kernel hiện tại có vẻ đang dùng môi trường ảo, phù hợp để chạy notebook.
# Đang dùng đúng môi trường mong muốn: tf-metal

# %%
# Kiểm tra và cài package theo đúng interpreter mà VS Code đang dùng
import importlib
import importlib.util
import shutil
import subprocess
import sys

REQUIRED_PACKAGES = {
    'ipykernel': 'ipykernel',
    'numpy': 'numpy',
    'scipy': 'scipy',
    'nltk': 'nltk',
    'tensorflow': 'tensorflow',
    'PIL': 'pillow',
}

OPTIONAL_PACKAGES = {}
if IS_APPLE_SILICON:
    OPTIONAL_PACKAGES['tensorflow_metal'] = 'tensorflow-metal'

missing_packages = []
for module_name, package_name in REQUIRED_PACKAGES.items():
    try:
        importlib.import_module(module_name)
    except ImportError:
        missing_packages.append(package_name)

if missing_packages:
    print('Đang cài các package còn thiếu:', missing_packages)
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', *missing_packages])
    print('Cài đặt hoàn tất.')
    print('Vui lòng Restart Kernel trong VS Code rồi chạy lại từ cell đầu để Python nạp package mới đúng cách.')
else:
    print('Môi trường đã đủ package cần thiết.')

missing_optional_packages = []
for module_name, package_name in OPTIONAL_PACKAGES.items():
    if importlib.util.find_spec(module_name) is None:
        missing_optional_packages.append(package_name)

if missing_optional_packages:
    print('Thiếu package tăng tốc tùy chọn:', missing_optional_packages)
    print('Trên Mac Apple Silicon, tensorflow-metal là hướng dùng GPU qua Metal, nhưng cần kiểm tra tương thích phiên bản trước khi cài.')
else:
    if OPTIONAL_PACKAGES:
        print('Các package tăng tốc tùy chọn đã sẵn sàng.')

# Kiểm tra GPU nếu máy có cài NVIDIA utilities
if shutil.which('nvidia-smi'):
    subprocess.run(['nvidia-smi'], check=False)
else:
    print('Không tìm thấy nvidia-smi. Nếu bạn chạy CPU thì có thể bỏ qua.')

print(f'Python executable (cell cài package): {sys.executable}')
# Out:
# Môi trường đã đủ package cần thiết.
# Thiếu package tăng tốc tùy chọn: ['tensorflow-metal']
# Trên Mac Apple Silicon, tensorflow-metal là hướng dùng GPU qua Metal, nhưng cần kiểm tra tương thích phiên bản trước khi cài.
# Không tìm thấy nvidia-smi. Nếu bạn chạy CPU thì có thể bỏ qua.
# Python executable (cell cài package): /opt/anaconda3/envs/tf-metal/bin/python

# %%
import os
import string
import re
import gc
import json
import math
import importlib.util
import numpy as np
import zipfile
from PIL import Image
from urllib.request import urlretrieve
from pickle import dump, load
from os import listdir
from os.path import join

import tensorflow as tf
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, Add
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

from nltk.translate.bleu_score import corpus_bleu
import nltk
nltk.download('punkt', quiet=True)

gpu_devices = tf.config.list_physical_devices('GPU')
has_tensorflow_metal = importlib.util.find_spec('tensorflow_metal') is not None

print(f'Pillow version: {Image.__version__}')
print(f'TensorFlow version: {tf.__version__}')
print(f'GPU khả dụng: {gpu_devices}')
print(f'Thư mục hiện tại: {Path.cwd()}')
print(f'WORK_DIR tồn tại: {WORK_DIR.exists()}')
print(f'tensorflow-metal đã cài: {has_tensorflow_metal}')

if IS_APPLE_SILICON and not gpu_devices:
    if has_tensorflow_metal:
        print('Mac có Apple GPU, nhưng TensorFlow hiện vẫn đang chạy CPU. Hãy kiểm tra phiên bản tensorflow/tensorflow-metal và kernel VS Code.')
    else:
        print('Mac có Apple GPU, nhưng TensorFlow hiện đang chạy CPU. Môi trường này chưa có tensorflow-metal, hoặc chưa có cấu hình tương thích để dùng Metal.')
elif gpu_devices:
    print('TensorFlow đã nhận GPU để tăng tốc.')
else:
    print('TensorFlow hiện đang chạy CPU.')
# Out:
# Pillow version: 12.1.1
# TensorFlow version: 2.16.2
# GPU khả dụng: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Thư mục hiện tại: /Applications/Python_AI/Neural_Image_Caption_Generation
# WORK_DIR tồn tại: True
# tensorflow-metal đã cài: False
# TensorFlow đã nhận GPU để tăng tốc.

# %% [markdown]
# ## 1. Tai dataset Flickr8k
#
# Dataset được host trên GitHub releases của tác giả Jason Brownlee. Gồm 2 file zip:
# - `Flickr8k_Dataset.zip` (~1GB): 8,092 ảnh JPEG
# - `Flickr8k_text.zip` (~3MB): file mô tả, file phân chia train/dev/test

# %%
# Tải dataset Flickr8k từ GitHub releases
flickr8k_images = os.path.join(WORK_DIR, 'Flicker8k_Dataset')
possible_text_dirs = [
    os.path.join(WORK_DIR, 'Flickr8k_text'),
    str(WORK_DIR),
]
required_text_files = [
    'Flickr8k.token.txt',
    'Flickr_8k.trainImages.txt',
    'Flickr_8k.devImages.txt',
    'Flickr_8k.testImages.txt',
]


def resolve_text_dir():
    for candidate in possible_text_dirs:
        if all(os.path.exists(os.path.join(candidate, filename)) for filename in required_text_files):
            return candidate
    return os.path.join(WORK_DIR, 'Flickr8k_text')


def image_dataset_ready(image_dir):
    return os.path.isdir(image_dir) and len(listdir(image_dir)) >= 8000


def text_dataset_ready(text_dir):
    return all(os.path.exists(os.path.join(text_dir, filename)) for filename in required_text_files)


def download_and_extract(url, archive_name, output_dir):
    archive_path = os.path.join(WORK_DIR, archive_name)
    print(f'Đang tải {archive_name}...')
    urlretrieve(url, archive_path)
    with zipfile.ZipFile(archive_path, 'r') as z:
        z.extractall(output_dir)
    os.remove(archive_path)
    print(f'Đã giải nén {archive_name}.')


flickr8k_text = resolve_text_dir()

if not image_dataset_ready(flickr8k_images):
    download_and_extract(
        'https://github.com/jbrownlee/Datasets/releases/download/Flickr8k/Flickr8k_Dataset.zip',
        'Flickr8k_Dataset.zip',
        WORK_DIR,
    )
    print(f'Giải nén xong. Số ảnh: {len(listdir(flickr8k_images))}')
else:
    print(f'Dataset ảnh đã có. Số ảnh: {len(listdir(flickr8k_images))}')

flickr8k_text = resolve_text_dir()
if not text_dataset_ready(flickr8k_text):
    download_and_extract(
        'https://github.com/jbrownlee/Datasets/releases/download/Flickr8k/Flickr8k_text.zip',
        'Flickr8k_text.zip',
        WORK_DIR,
    )
    flickr8k_text = resolve_text_dir()
    if text_dataset_ready(flickr8k_text):
        print(f'Dataset text đã sẵn sàng tại: {flickr8k_text}')
    else:
        raise FileNotFoundError('Đã tải text dataset nhưng chưa tìm thấy đủ file Flickr8k cần thiết.')
else:
    print(f'Dataset text đã có tại: {flickr8k_text}')
# Out:
# Dataset ảnh đã có. Số ảnh: 8091
# Dataset text đã có tại: /Applications/Python_AI/Neural_Image_Caption_Generation/workspace

# %% [markdown]
# ## 2. Trich xuat dac trung anh VGG16
#
# Cell nay trich xuat hai loai dac trung anh tu VGG16: `features_fc` va `features_conv`, sau do luu ra file pickle de tai su dung.

# %%
def extract_features_dual(directory):
    """Trích xuất đặc trưng ảnh từ VGG16.

    Trả về hai dict:
    - features_fc: {image_id: np.array (1, 4096)} cho mô hình LSTM
    - features_conv: {image_id: np.array (49, 512)} cho mô hình Transformer

    Lưu ý shape:
    - features_fc lưu shape (1, 4096) — GIỮ batch dimension vì model_fc.predict()
      trả về (1, 4096). Khi tạo training data, photos[key][0] lấy ra vector (4096,)
      rồi append vào list, cuối cùng np.array() stack thành (N, 4096).
    - features_conv lưu shape (49, 512) — ĐÃ BỎ batch dimension. Khi tạo training data,
      photos[key] trực tiếp append, np.array() stack thành (N, 49, 512).
    """
    # Tải mô hình VGG16 đã huấn luyện trên ImageNet
    base_model = VGG16()

    # Mô hình 1: đầu ra lớp FC thứ hai từ cuối → (1, 4096)
    model_fc = Model(inputs=base_model.inputs,
                     outputs=base_model.layers[-2].output)

    # Mô hình 2: đầu ra block5_pool → (1, 7, 7, 512)
    model_conv = Model(inputs=base_model.inputs,
                       outputs=base_model.get_layer('block5_pool').output)

    features_fc = dict()
    features_conv = dict()
    filenames = listdir(directory)
    total = len(filenames)

    for i, name in enumerate(filenames):
        filepath = join(directory, name)
        # Tải ảnh, resize về 224×224, chuyển thành mảng numpy
        image = load_img(filepath, target_size=(224, 224))
        image = img_to_array(image)
        # Thêm batch dimension: (224,224,3) → (1,224,224,3)
        image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
        # Tiền xử lý theo chuẩn ImageNet (trừ mean RGB)
        image = preprocess_input(image)

        # Trích xuất đặc trưng
        feat_fc = model_fc.predict(image, verbose=0)      # (1, 4096)
        feat_conv = model_conv.predict(image, verbose=0)   # (1, 7, 7, 512)

        # Lấy image_id từ tên file (bỏ phần mở rộng .jpg)
        image_id = name.split('.')[0]
        features_fc[image_id] = feat_fc                     # giữ (1, 4096)
        features_conv[image_id] = feat_conv.reshape(
            feat_conv.shape[1] * feat_conv.shape[2], feat_conv.shape[3]
        )  # (7*7, 512) = (49, 512)

        if (i + 1) % 500 == 0:
            print(f'  Đã xử lý {i+1}/{total} ảnh...')

    return features_fc, features_conv

# Kiểm tra file đã trích xuất chưa — tránh chạy lại
fc_path = os.path.join(WORK_DIR, 'features_fc.pkl')
conv_path = os.path.join(WORK_DIR, 'features_conv.pkl')

if not (os.path.exists(fc_path) and os.path.exists(conv_path)):
    print('Trích xuất đặc trưng ảnh (mất ~10-30 phút)...')
    features_fc, features_conv = extract_features_dual(flickr8k_images)
    with open(fc_path, 'wb') as fc_file:
        dump(features_fc, fc_file)
    with open(conv_path, 'wb') as conv_file:
        dump(features_conv, conv_file)
    print(f'Đã lưu. Số ảnh: {len(features_fc)}')
    print(f'  features_fc shape mẫu: {list(features_fc.values())[0].shape}')
    print(f'  features_conv shape mẫu: {list(features_conv.values())[0].shape}')
else:
    print('Đặc trưng ảnh đã có sẵn, bỏ qua bước trích xuất.')
# Out:
# Đặc trưng ảnh đã có sẵn, bỏ qua bước trích xuất.

# %% [markdown]
# ## 3. Lam sach mo ta caption
#
# Cell nay doc caption goc, lam sach text, tao `descriptions.txt`, va chuan bi du lieu mo ta cho cac buoc train/test sau do.

# %%
def load_doc(filename):
    """Đọc toàn bộ nội dung file văn bản."""
    with open(filename, 'r') as f:
        return f.read()

def load_descriptions(doc):
    """Phân tích file Flickr8k.token.txt thành dict {image_id: [desc1, desc2, ...]}.

    Mỗi ảnh có 5 mô tả. image_id là tên file bỏ phần mở rộng .jpg.
    Format dòng: tên_file.jpg#N<tab>mô_tả
    """
    mapping = dict()
    for line in doc.split('\n'):
        tokens = line.split()
        if len(line) < 2:
            continue
        # tokens[0] = 'xxx.jpg#0', tokens[1:] = các từ trong mô tả
        image_id, image_desc = tokens[0], tokens[1:]
        # Bỏ phần .jpg#N, chỉ giữ image_id
        image_id = image_id.split('.')[0]
        image_desc = ' '.join(image_desc)
        if image_id not in mapping:
            mapping[image_id] = list()
        mapping[image_id].append(image_desc)
    return mapping

def clean_descriptions(descriptions):
    """Làm sạch tất cả mô tả: viết thường, bỏ dấu câu, bỏ từ ngắn/chứa số."""
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    for _, desc_list in descriptions.items():
        for i in range(len(desc_list)):
            desc = desc_list[i]
            desc = desc.split()
            # Chuyển chữ thường
            desc = [word.lower() for word in desc]
            # Bỏ dấu câu
            desc = [re_punc.sub('', w) for w in desc]
            # Bỏ từ có 1 ký tự trở xuống (sau khi bỏ dấu câu)
            desc = [word for word in desc if len(word) > 1]
            # Chỉ giữ từ toàn chữ cái (bỏ từ chứa số)
            desc = [word for word in desc if word.isalpha()]
            desc_list[i] = ' '.join(desc)

def to_vocabulary(descriptions):
    """Tạo tập từ vựng (set) từ tất cả mô tả."""
    all_desc = set()
    for key in descriptions.keys():
        [all_desc.update(d.split()) for d in descriptions[key]]
    return all_desc

def save_descriptions(descriptions, filename):
    """Lưu mô tả đã làm sạch ra file text.
    Mỗi dòng: image_id mô_tả (không có startseq/endseq ở bước này).
    """
    lines = list()
    for key, desc_list in descriptions.items():
        for desc in desc_list:
            lines.append(key + ' ' + desc)
    data = '\n'.join(lines)
    with open(filename, 'w') as f:
        f.write(data)

# --- Thực thi pipeline làm sạch ---
token_file = os.path.join(flickr8k_text, 'Flickr8k.token.txt')
doc = load_doc(token_file)
descriptions = load_descriptions(doc)
print(f'Số ảnh có mô tả: {len(descriptions)}')

# In mẫu trước khi làm sạch
sample_key = list(descriptions.keys())[0]
print(f'\nMẫu trước làm sạch ({sample_key}):')
for d in descriptions[sample_key][:2]:
    print(f'  {d}')

clean_descriptions(descriptions)
vocabulary = to_vocabulary(descriptions)
print(f'\nKích thước từ vựng sau làm sạch: {len(vocabulary)}')

# In mẫu sau khi làm sạch
print(f'\nMẫu sau làm sạch ({sample_key}):')
for d in descriptions[sample_key][:2]:
    print(f'  {d}')

# Lưu file
desc_file = os.path.join(WORK_DIR, 'descriptions.txt')
save_descriptions(descriptions, desc_file)
print(f'\nĐã lưu mô tả vào: {desc_file}')
# Out:
# Số ảnh có mô tả: 8092
#
# Mẫu trước làm sạch (1000268201_693b08cb0e):
#   A child in a pink dress is climbing up a set of stairs in an entry way .
#   A girl going into a wooden building .
#
# Kích thước từ vựng sau làm sạch: 8763
#
# Mẫu sau làm sạch (1000268201_693b08cb0e):
#   child in pink dress is climbing up set of stairs in an entry way
#   girl going into wooden building
#
# Đã lưu mô tả vào: /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/descriptions.txt

# %% [markdown]
# ## 4. Nap train/dev/test va tokenizer
#
# Cell nay nap train/dev/test split, descriptions da clean, feature files, va tao tokenizer cho tap train.

# %%
def load_set(filename):
    """Tải danh sách image_id từ file phân chia train/dev/test.

    File có format: mỗi dòng là tên_file.jpg
    """
    doc = load_doc(filename)
    dataset = list()
    for line in doc.split('\n'):
        if len(line) < 1:
            continue
        identifier = line.split('.')[0]
        dataset.append(identifier)
    return set(dataset)

def load_clean_descriptions(filename, dataset):
    """Tải mô tả đã làm sạch, thêm startseq/endseq, lọc theo dataset."""
    doc = load_doc(filename)
    descriptions = dict()
    for line in doc.split('\n'):
        tokens = line.split()
        if len(tokens) < 2:
            continue
        image_id, image_desc = tokens[0], tokens[1:]
        if image_id in dataset:
            if image_id not in descriptions:
                descriptions[image_id] = list()
            desc = 'startseq ' + ' '.join(image_desc) + ' endseq'
            descriptions[image_id].append(desc)
    return descriptions

def load_photo_features(filename, dataset):
    """Tải đặc trưng ảnh từ file pickle, chỉ giữ ảnh trong dataset."""
    with open(filename, 'rb') as feature_file:
        all_features = load(feature_file)
    return {k: all_features[k] for k in dataset if k in all_features}

def to_lines(descriptions):
    all_desc = list()
    for key in descriptions.keys():
        [all_desc.append(d) for d in descriptions[key]]
    return all_desc

def create_tokenizer(descriptions, max_vocab_size=7000):
    """Tạo tokenizer có giới hạn vocab vừa phải để giảm unk nhưng vẫn ổn định khi train."""
    lines = to_lines(descriptions)
    tokenizer = Tokenizer(num_words=max_vocab_size, oov_token='unk')
    tokenizer.fit_on_texts(lines)
    return tokenizer

def calc_max_length(descriptions):
    lines = to_lines(descriptions)
    return max(len(d.split()) for d in lines)

print('--- Tải dữ liệu train ---')
train_file = os.path.join(flickr8k_text, 'Flickr_8k.trainImages.txt')
train_set = load_set(train_file)
print(f'Số ảnh train: {len(train_set)}')

train_descriptions = load_clean_descriptions(desc_file, train_set)
print(f'Số ảnh có mô tả trong train: {len(train_descriptions)}')

train_features_fc = load_photo_features(fc_path, train_set)
print(f'Đặc trưng FC train: {len(train_features_fc)}')

train_features_conv = load_photo_features(conv_path, train_set)
print(f'Đặc trưng Conv train: {len(train_features_conv)}')

max_vocab_size = 7000
tokenizer = create_tokenizer(train_descriptions, max_vocab_size=max_vocab_size)
raw_vocab_size = len(tokenizer.word_index) + 1
vocab_size = min(max_vocab_size, raw_vocab_size)
print(f'Kích thước từ vựng gốc: {raw_vocab_size}')
print(f'Kích thước từ vựng dùng để train attention: {vocab_size}')

max_length = calc_max_length(train_descriptions)
print(f'Độ dài mô tả tối đa: {max_length}')

sample_desc = to_lines(train_descriptions)[0]
sample_seq = tokenizer.texts_to_sequences([sample_desc])[0]
print(f'\nMẫu tokenization:')
print(f'  Text: {sample_desc}')
print(f'  Sequence: {sample_seq}')

with open(os.path.join(WORK_DIR, 'tokenizer.pkl'), 'wb') as tokenizer_file:
    dump(tokenizer, tokenizer_file)
print('\nĐã lưu tokenizer.')

print('\n--- Tải dữ liệu dev ---')
dev_file = os.path.join(flickr8k_text, 'Flickr_8k.devImages.txt')
dev_set = load_set(dev_file)
dev_descriptions = load_clean_descriptions(desc_file, dev_set)
dev_features_fc = load_photo_features(fc_path, dev_set)
dev_features_conv = load_photo_features(conv_path, dev_set)
print(f'Số ảnh dev: {len(dev_set)}, mô tả: {len(dev_descriptions)}')

print('\n--- Tải dữ liệu test ---')
test_file = os.path.join(flickr8k_text, 'Flickr_8k.testImages.txt')
test_set = load_set(test_file)
test_descriptions = load_clean_descriptions(desc_file, test_set)
test_features_fc = load_photo_features(fc_path, test_set)
test_features_conv = load_photo_features(conv_path, test_set)
print(f'Số ảnh test: {len(test_set)}, mô tả: {len(test_descriptions)}')
# Out:
# --- Tải dữ liệu train ---
# Số ảnh train: 6000
# Số ảnh có mô tả trong train: 6000
# Đặc trưng FC train: 6000
# Đặc trưng Conv train: 6000
# Kích thước từ vựng gốc: 7580
# Kích thước từ vựng dùng để train attention: 7000
# Độ dài mô tả tối đa: 34
#
# Mẫu tokenization:
#   Text: startseq child in pink dress is climbing up set of stairs in an entry way endseq
#   Sequence: [2, 43, 4, 88, 170, 7, 118, 56, 394, 12, 395, 4, 28, 4475, 641, 3]
#
# Đã lưu tokenizer.
#
# --- Tải dữ liệu dev ---
# Số ảnh dev: 1000, mô tả: 1000
#
# --- Tải dữ liệu test ---
# Số ảnh test: 1000, mô tả: 1000

# %% [markdown]
# ## 5. Chuan bi GloVe embeddings
#
# Cell nay tim file GloVe o local, tao `embedding_matrix`, va se dung no de khoi tao word embedding cho attention model.
# Notebook uu tien `glove.6B.100d.txt` de giu bo nho va thoi gian train o muc hop ly.

# %%
def find_glove_file():
    """Tìm file GloVe local trong một số vị trí phổ biến."""
    candidate_paths = [
        PROJECT_ROOT / 'glove.6B.100d.txt',
        PROJECT_ROOT / 'glove.6B' / 'glove.6B.100d.txt',
        WORK_DIR / 'glove.6B.100d.txt',
        WORK_DIR / 'glove' / 'glove.6B.100d.txt',
    ]
    for path in candidate_paths:
        if path.exists():
            return path
    return None


def build_glove_embedding_matrix(tokenizer, vocab_size, glove_path):
    """Tạo embedding matrix từ file GloVe cho vocab hiện tại."""
    embedding_index = {}
    with open(glove_path, 'r', encoding='utf-8') as glove_file:
        for line in glove_file:
            values = line.strip().split()
            if not values:
                continue
            word = values[0]
            vector = np.asarray(values[1:], dtype='float32')
            embedding_index[word] = vector

    embedding_dim = len(next(iter(embedding_index.values())))
    embedding_matrix = np.random.normal(loc=0.0, scale=0.6, size=(vocab_size, embedding_dim)).astype('float32')
    embedding_matrix[0] = 0.0

    hits = 0
    for word, index in tokenizer.word_index.items():
        if index >= vocab_size:
            continue
        vector = embedding_index.get(word)
        if vector is not None:
            embedding_matrix[index] = vector
            hits += 1

    return embedding_matrix, embedding_dim, hits, len(embedding_index)


glove_path = find_glove_file()
embedding_matrix = None
embedding_dim = 100
embedding_trainable = False

if glove_path is None:
    print('Khong tim thay file GloVe local.')
    print('Hay dat file glove.6B.100d.txt vao mot trong cac vi tri sau:')
    print(f'  - {PROJECT_ROOT / "glove.6B.100d.txt"}')
    print(f'  - {PROJECT_ROOT / "glove.6B" / "glove.6B.100d.txt"}')
    print(f'  - {WORK_DIR / "glove.6B.100d.txt"}')
    print(f'  - {WORK_DIR / "glove" / "glove.6B.100d.txt"}')
    print('Notebook van co the train tiep bang embedding ngau nhien neu ban muon.')
else:
    embedding_matrix, embedding_dim, glove_hits, glove_vocab_size = build_glove_embedding_matrix(
        tokenizer=tokenizer,
        vocab_size=vocab_size,
        glove_path=glove_path,
    )
    glove_coverage = glove_hits / max(1, vocab_size - 1)
    print(f'Da tim thay GloVe: {glove_path}')
    print(f'Embedding dim: {embedding_dim}')
    print(f'So tu GloVe load duoc: {glove_hits}/{max(1, vocab_size - 1)} ({glove_coverage:.2%})')
    print(f'Kich thuoc tu dien GloVe: {glove_vocab_size:,}')
    print(f'Embedding trainable: {embedding_trainable}')
# Out:
# Da tim thay GloVe: /Applications/Python_AI/Neural_Image_Caption_Generation/glove.6B.100d.txt
# Embedding dim: 100
# So tu GloVe load duoc: 6361/6999 (90.88%)
# Kich thuoc tu dien GloVe: 400,000
# Embedding trainable: False

# %% [markdown]
# ## 6. Tao dataset attention
#
# Cell nay tao pipeline dataset streaming cho attention model tu `features_conv`, de train khong ton qua nhieu RAM.

# %%
def normalize_photo_feature(photo_feature):
    """Chuẩn hóa đặc trưng ảnh cho cả vector FC và lưới Conv."""
    photo_feature = np.asarray(photo_feature, dtype='float32')
    if photo_feature.ndim == 1:
        norm = np.linalg.norm(photo_feature)
        if norm > 0:
            photo_feature = photo_feature / norm
    elif photo_feature.ndim == 2:
        norms = np.linalg.norm(photo_feature, axis=1, keepdims=True)
        photo_feature = photo_feature / np.maximum(norms, 1e-8)
    return photo_feature

def count_caption_samples(descriptions, photos):
    total = 0
    for key, desc_list in descriptions.items():
        if key not in photos:
            continue
        for desc in desc_list:
            seq_len = len(desc.split())
            total += max(0, seq_len - 1)
    return total

def caption_sample_generator(tokenizer, max_length, descriptions, photos):
    for key, desc_list in descriptions.items():
        if key not in photos:
            continue
        photo_feature = normalize_photo_feature(photos[key])
        for desc in desc_list:
            seq = tokenizer.texts_to_sequences([desc])[0]
            for i in range(1, len(seq)):
                in_seq, out_seq = seq[:i], seq[i]
                in_seq = pad_sequences([in_seq], maxlen=max_length, padding='post')[0].astype('int32')
                yield (photo_feature.astype('float32'), in_seq), np.int32(out_seq)

def build_caption_dataset(tokenizer, max_length, descriptions, photos, batch_size, shuffle=False):
    output_signature = ((
        tf.TensorSpec(shape=(49, 512), dtype=tf.float32),
        tf.TensorSpec(shape=(max_length,), dtype=tf.int32),
    ), tf.TensorSpec(shape=(), dtype=tf.int32))
    dataset = tf.data.Dataset.from_generator(
        lambda: caption_sample_generator(tokenizer, max_length, descriptions, photos),
        output_signature=output_signature,
    )
    if shuffle:
        sample_count = count_caption_samples(descriptions, photos)
        dataset = dataset.shuffle(min(sample_count, 4096), reshuffle_each_iteration=True)
    return dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

def clear_legacy_training_arrays():
    legacy_names = ['X1train', 'X2train', 'ytrain', 'X1dev', 'X2dev', 'ydev']
    removed = []
    for name in legacy_names:
        if name in globals():
            del globals()[name]
            removed.append(name)
    gc.collect()
    if removed:
        print(f'Da giai phong bien RAM cu: {removed}')

clear_legacy_training_arrays()

print('Tinh so cap input-output cho tap train/dev (khong materialize vao RAM)...')
train_sample_count = count_caption_samples(train_descriptions, train_features_conv)
dev_sample_count = count_caption_samples(dev_descriptions, dev_features_conv)
print(f'  Train sample count: {train_sample_count:,}')
print(f'  Dev sample count: {dev_sample_count:,}')
print('  Du lieu se duoc stream theo batch tu features_conv (49, 512) de train attention model.')
# Out:
# Tinh so cap input-output cho tap train/dev (khong materialize vao RAM)...
#   Train sample count: 306,404
#   Dev sample count: 51,622
#   Du lieu se duoc stream theo batch tu features_conv (49, 512) de train attention model.

# %% [markdown]
# ## 7. Xay dung attention model
#
# Cell nay dinh nghia mo hinh attention dung `features_conv` cua VGG16 va word embeddings co the khoi tao bang GloVe.

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input,
    Dense,
    LSTM,
    Embedding,
    Dropout,
    AdditiveAttention,
    Concatenate,
    Flatten,
    Reshape,
    GlobalAveragePooling1D,
)


def define_model_attention(
    vocab_size,
    max_length,
    learning_rate=5e-5,
    embedding_matrix=None,
    embedding_dim=100,
    embedding_trainable=False,
):
    """Định nghĩa image captioning model dùng VGG16 conv features + attention + GloVe tùy chọn."""
    image_input = Input(shape=(49, 512), name='image_regions_input')
    image_regions = Dropout(0.3, name='image_dropout')(image_input)
    image_regions = Dense(256, activation='relu', name='image_projection')(image_regions)
    image_regions = Dropout(0.2, name='image_projection_dropout')(image_regions)
    image_global = GlobalAveragePooling1D(name='image_global_pool')(image_regions)

    sequence_input = Input(shape=(max_length,), name='sequence_input')
    embedding_kwargs = dict(input_dim=vocab_size, output_dim=embedding_dim, mask_zero=True, name='word_embedding')
    if embedding_matrix is not None:
        embedding_kwargs['weights'] = [embedding_matrix]
        embedding_kwargs['trainable'] = embedding_trainable
    sequence_embedding = Embedding(**embedding_kwargs)(sequence_input)
    sequence_embedding = Dropout(0.3, name='embedding_dropout')(sequence_embedding)
    _, state_h, _ = LSTM(
        256,
        return_sequences=True,
        return_state=True,
        dropout=0.2,
        recurrent_dropout=0.0,
        name='caption_lstm',
    )(sequence_embedding)

    query = Reshape((1, 256), name='attention_query')(state_h)
    attention_context = AdditiveAttention(name='image_attention')([query, image_regions])
    attention_context = Flatten(name='flatten_attention_context')(attention_context)

    decoder = Concatenate(name='decoder_concat')([attention_context, image_global, state_h])
    decoder = Dense(256, activation='relu', name='decoder_dense')(decoder)
    decoder = Dropout(0.3, name='decoder_dropout')(decoder)
    outputs = Dense(vocab_size, activation='softmax', name='word_distribution')(decoder)

    optimizer = Adam(learning_rate=learning_rate, clipnorm=1.0)
    model = Model(inputs=[image_input, sequence_input], outputs=outputs, name='caption_attention_model')
    model.compile(
        loss='sparse_categorical_crossentropy',
        optimizer=optimizer,
        metrics=['sparse_categorical_accuracy'],
    )
    return model


tf.keras.backend.clear_session()
model_lstm = define_model_attention(
    vocab_size,
    max_length,
    embedding_matrix=embedding_matrix,
    embedding_dim=embedding_dim,
    embedding_trainable=embedding_trainable,
)
model_lstm.summary()
# Out:
# Model: "caption_attention_model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ sequence_input      │ (None, 34)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ word_embedding      │ (None, 34, 100)   │    700,000 │ sequence_input[0… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ image_regions_input │ (None, 49, 512)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_dropout   │ (None, 34, 100)   │          0 │ word_embedding[0… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal           │ (None, 34)        │          0 │ sequence_input[0… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ image_dropout       │ (None, 49, 512)   │          0 │ image_regions_in… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ caption_lstm (LSTM) │ [(None, 34, 256), │    365,568 │ embedding_dropou… │
# │                     │ (None, 256),      │            │ not_equal[0][0]   │
# │                     │ (None, 256)]      │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ image_projection    │ (None, 49, 256)   │    131,328 │ image_dropout[0]… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attention_query     │ (None, 1, 256)    │          0 │ caption_lstm[0][… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ image_projection_d… │ (None, 49, 256)   │          0 │ image_projection… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ image_attention     │ (None, 1, 256)    │        256 │ attention_query[… │
# │ (AdditiveAttention) │                   │            │ image_projection… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_attention_… │ (None, 256)       │          0 │ image_attention[… │
# │ (Flatten)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ image_global_pool   │ (None, 256)       │          0 │ image_projection… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_concat      │ (None, 768)       │          0 │ flatten_attentio… │
# │ (Concatenate)       │                   │            │ image_global_poo… │
# │                     │                   │            │ caption_lstm[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_dense       │ (None, 256)       │    196,864 │ decoder_concat[0… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ decoder_dropout     │ (None, 256)       │          0 │ decoder_dense[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ word_distribution   │ (None, 7000)      │  1,799,000 │ decoder_dropout[… │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,193,016 (12.18 MB)
#  Trainable params: 2,493,016 (9.51 MB)
#  Non-trainable params: 700,000 (2.67 MB)

# %% [markdown]
# ## 8. Huan luyen mo hinh attention
#
# Phan nay train model captioning su dung `features_conv` cua VGG16 va co co che attention de hoc tot hon bo cuc khong gian cua anh.

# %% [markdown]
# ## 8.1. Cau hinh train attention
#
# Cell nay cau hinh duong dan model, callback, dataset train/dev, va cac hyperparameters de huan luyen mo hinh attention.

# %%
MODEL_DIR = WORK_DIR / 'models'
MODEL_DIR.mkdir(parents=True, exist_ok=True)

model_path = MODEL_DIR / 'caption_model_attention.keras'
history_path = MODEL_DIR / 'caption_model_attention_history.json'

force_train = True
epochs = 40
batch_size = 64
learning_rate = 5e-5

clear_legacy_training_arrays()
gc.collect()

train_dataset = build_caption_dataset(
    tokenizer, max_length, train_descriptions, train_features_conv, batch_size=batch_size, shuffle=True
).repeat()
dev_dataset = build_caption_dataset(
    tokenizer, max_length, dev_descriptions, dev_features_conv, batch_size=batch_size, shuffle=False
).repeat()

steps_per_epoch = math.ceil(train_sample_count / batch_size)
validation_steps = math.ceil(dev_sample_count / batch_size)

(sample_inputs, sample_targets) = next(iter(train_dataset.take(1)))
sample_images, sample_sequences = sample_inputs

callbacks = [
    ModelCheckpoint(
        filepath=str(model_path),
        monitor='val_loss',
        save_best_only=True,
        verbose=1,
    ),
    EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True,
        verbose=1,
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=1,
        min_lr=1e-6,
        verbose=1,
    ),
]

print(f'Lưu model tại: {model_path}')
print(f'Lưu history tại: {history_path}')
print(f'force_train: {force_train}')
print(f'Epochs: {epochs}, batch_size: {batch_size}, learning_rate: {learning_rate}')
print(f'Kích thước vocab train attention: {vocab_size}')
print(f'Embedding dim: {embedding_dim}, embedding_trainable: {embedding_trainable}')
print(f'GloVe active: {embedding_matrix is not None}')
print(f'Train samples: {train_sample_count:,}, steps/epoch: {steps_per_epoch}')
print(f'Dev samples: {dev_sample_count:,}, validation_steps: {validation_steps}')
print(f'Sample image batch: {sample_images.shape}, dtype={sample_images.dtype}')
print(f'Sample sequence batch: {sample_sequences.shape}, dtype={sample_sequences.dtype}')
print(f'Sample target batch: {sample_targets.shape}, dtype={sample_targets.dtype}')
print('Dataset train/dev da repeat theo epoch de tranh OUT_OF_RANGE khi train nhieu epoch.')
print('Attention model dang dung features_conv (49, 512) thay vi features_fc (4096).')
# Out:
# Lưu model tại: /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# Lưu history tại: /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention_history.json
# force_train: True
# Epochs: 40, batch_size: 64, learning_rate: 5e-05
# Kích thước vocab train attention: 7000
# Embedding dim: 100, embedding_trainable: False
# GloVe active: True
# Train samples: 306,404, steps/epoch: 4788
# Dev samples: 51,622, validation_steps: 807
# Sample image batch: (64, 49, 512), dtype=<dtype: 'float32'>
# Sample sequence batch: (64, 34), dtype=<dtype: 'int32'>
# Sample target batch: (64,), dtype=<dtype: 'int32'>
# Dataset train/dev da repeat theo epoch de tranh OUT_OF_RANGE khi train nhieu epoch.
# Attention model dang dung features_conv (49, 512) thay vi features_fc (4096).

# %% [markdown]
# ## 8.2. Train attention model
#
# Cell nay thuc hien huan luyen hoac load checkpoint attention model tuy theo `force_train` va trang thai file model.

# %%
history = None

if model_path.exists() and not force_train:
    print('Đã tìm thấy model attention đã train trước đó, sẽ load để evaluate/inference.')
    model_lstm = load_model(model_path)
else:
    tf.keras.backend.clear_session()
    model_lstm = define_model_attention(
        vocab_size,
        max_length,
        learning_rate=learning_rate,
        embedding_matrix=embedding_matrix,
        embedding_dim=embedding_dim,
        embedding_trainable=embedding_trainable,
    )
    if model_path.exists() and force_train:
        print('Đã có checkpoint attention cũ, nhưng force_train=True nên sẽ train lại và cập nhật best model.')
    else:
        print('Chưa có model attention đã train, bắt đầu huấn luyện...')
    history = model_lstm.fit(
        train_dataset,
        validation_data=dev_dataset,
        epochs=epochs,
        steps_per_epoch=steps_per_epoch,
        validation_steps=validation_steps,
        callbacks=callbacks,
        verbose=1,
    )
    with open(history_path, 'w', encoding='utf-8') as history_file:
        json.dump(history.history, history_file, ensure_ascii=False, indent=2)
    print('Huấn luyện xong và đã lưu history.')

if model_path.exists():
    model_lstm = load_model(model_path)
    print('Đã load best attention model từ checkpoint.')
# Out:
# Đã có checkpoint attention cũ, nhưng force_train=True nên sẽ train lại và cập nhật best model.
# Epoch 1/40
# 2026-03-18 09:39:52.765627: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 6.1043 - sparse_categorical_accuracy: 0.0962
# Epoch 1: val_loss improved from None to 5.22667, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 132s 27ms/step - loss: 5.7404 - sparse_categorical_accuracy: 0.1093 - val_loss: 5.2267 - val_sparse_categorical_accuracy: 0.1398 - learning_rate: 5.0000e-05
# Epoch 2/40
# 4787/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 5.2091 - sparse_categorical_accuracy: 0.1463
# Epoch 2: val_loss improved from 5.22667 to 4.88091, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 126s 26ms/step - loss: 5.1505 - sparse_categorical_accuracy: 0.1498 - val_loss: 4.8809 - val_sparse_categorical_accuracy: 0.1723 - learning_rate: 5.0000e-05
# Epoch 3/40
# 4786/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.8896 - sparse_categorical_accuracy: 0.1732
# Epoch 3: val_loss improved from 4.88091 to 4.63249, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 118s 25ms/step - loss: 4.8434 - sparse_categorical_accuracy: 0.1774 - val_loss: 4.6325 - val_sparse_categorical_accuracy: 0.1956 - learning_rate: 5.0000e-05
# Epoch 4/40
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.6716 - sparse_categorical_accuracy: 0.1934
# Epoch 4: val_loss improved from 4.63249 to 4.47864, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 115s 24ms/step - loss: 4.6473 - sparse_categorical_accuracy: 0.1944 - val_loss: 4.4786 - val_sparse_categorical_accuracy: 0.2067 - learning_rate: 5.0000e-05
# Epoch 5/40
# 4786/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 4.5290 - sparse_categorical_accuracy: 0.2062
# Epoch 5: val_loss improved from 4.47864 to 4.35190, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 127s 27ms/step - loss: 4.5054 - sparse_categorical_accuracy: 0.2080 - val_loss: 4.3519 - val_sparse_categorical_accuracy: 0.2205 - learning_rate: 5.0000e-05
# Epoch 6/40
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.4057 - sparse_categorical_accuracy: 0.2169
# Epoch 6: val_loss improved from 4.35190 to 4.25139, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 117s 24ms/step - loss: 4.3885 - sparse_categorical_accuracy: 0.2175 - val_loss: 4.2514 - val_sparse_categorical_accuracy: 0.2309 - learning_rate: 5.0000e-05
# Epoch 7/40
# 4786/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.3028 - sparse_categorical_accuracy: 0.2251
# Epoch 7: val_loss improved from 4.25139 to 4.16375, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 117s 24ms/step - loss: 4.2922 - sparse_categorical_accuracy: 0.2247 - val_loss: 4.1637 - val_sparse_categorical_accuracy: 0.2386 - learning_rate: 5.0000e-05
# Epoch 8/40
# 4787/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.2275 - sparse_categorical_accuracy: 0.2323
# Epoch 8: val_loss improved from 4.16375 to 4.11527, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 116s 24ms/step - loss: 4.2177 - sparse_categorical_accuracy: 0.2313 - val_loss: 4.1153 - val_sparse_categorical_accuracy: 0.2415 - learning_rate: 5.0000e-05
# Epoch 9/40
# 4787/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1593 - sparse_categorical_accuracy: 0.2389
# Epoch 9: val_loss improved from 4.11527 to 4.04794, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 117s 24ms/step - loss: 4.1536 - sparse_categorical_accuracy: 0.2374 - val_loss: 4.0479 - val_sparse_categorical_accuracy: 0.2481 - learning_rate: 5.0000e-05
# Epoch 10/40
# 4787/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.1034 - sparse_categorical_accuracy: 0.2429
# Epoch 10: val_loss improved from 4.04794 to 3.99656, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 116s 24ms/step - loss: 4.0983 - sparse_categorical_accuracy: 0.2420 - val_loss: 3.9966 - val_sparse_categorical_accuracy: 0.2515 - learning_rate: 5.0000e-05
# Epoch 11/40
# 4786/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 4.0521 - sparse_categorical_accuracy: 0.2480
# Epoch 11: val_loss improved from 3.99656 to 3.98027, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 117s 24ms/step - loss: 4.0480 - sparse_categorical_accuracy: 0.2471 - val_loss: 3.9803 - val_sparse_categorical_accuracy: 0.2541 - learning_rate: 5.0000e-05
# Epoch 12/40
# 4786/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0073 - sparse_categorical_accuracy: 0.2514
# Epoch 12: val_loss improved from 3.98027 to 3.93456, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 118s 25ms/step - loss: 4.0054 - sparse_categorical_accuracy: 0.2497 - val_loss: 3.9346 - val_sparse_categorical_accuracy: 0.2590 - learning_rate: 5.0000e-05
# Epoch 13/40
# 4786/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.9669 - sparse_categorical_accuracy: 0.2545
# Epoch 13: val_loss improved from 3.93456 to 3.88799, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 116s 24ms/step - loss: 3.9640 - sparse_categorical_accuracy: 0.2536 - val_loss: 3.8880 - val_sparse_categorical_accuracy: 0.2638 - learning_rate: 5.0000e-05
# Epoch 14/40
# 4786/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.9351 - sparse_categorical_accuracy: 0.2581
# Epoch 14: val_loss improved from 3.88799 to 3.87449, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 117s 24ms/step - loss: 3.9314 - sparse_categorical_accuracy: 0.2567 - val_loss: 3.8745 - val_sparse_categorical_accuracy: 0.2658 - learning_rate: 5.0000e-05
# Epoch 15/40
# 4787/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.9017 - sparse_categorical_accuracy: 0.2602
# Epoch 15: val_loss improved from 3.87449 to 3.85653, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 117s 24ms/step - loss: 3.8973 - sparse_categorical_accuracy: 0.2599 - val_loss: 3.8565 - val_sparse_categorical_accuracy: 0.2674 - learning_rate: 5.0000e-05
# Epoch 16/40
# 4786/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.8693 - sparse_categorical_accuracy: 0.2630
# Epoch 16: val_loss improved from 3.85653 to 3.81877, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 116s 24ms/step - loss: 3.8680 - sparse_categorical_accuracy: 0.2622 - val_loss: 3.8188 - val_sparse_categorical_accuracy: 0.2720 - learning_rate: 5.0000e-05
# Epoch 17/40
# 4787/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.8378 - sparse_categorical_accuracy: 0.2667
# Epoch 17: val_loss improved from 3.81877 to 3.79796, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 116s 24ms/step - loss: 3.8373 - sparse_categorical_accuracy: 0.2652 - val_loss: 3.7980 - val_sparse_categorical_accuracy: 0.2745 - learning_rate: 5.0000e-05
# Epoch 18/40
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.8100 - sparse_categorical_accuracy: 0.2687
# Epoch 18: val_loss improved from 3.79796 to 3.79443, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 117s 24ms/step - loss: 3.8108 - sparse_categorical_accuracy: 0.2672 - val_loss: 3.7944 - val_sparse_categorical_accuracy: 0.2750 - learning_rate: 5.0000e-05
# Epoch 19/40
# 4786/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.7881 - sparse_categorical_accuracy: 0.2716
# Epoch 19: val_loss improved from 3.79443 to 3.78708, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 116s 24ms/step - loss: 3.7867 - sparse_categorical_accuracy: 0.2703 - val_loss: 3.7871 - val_sparse_categorical_accuracy: 0.2736 - learning_rate: 5.0000e-05
# Epoch 20/40
# 4787/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.7652 - sparse_categorical_accuracy: 0.2743
# Epoch 20: val_loss improved from 3.78708 to 3.75190, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 117s 24ms/step - loss: 3.7647 - sparse_categorical_accuracy: 0.2725 - val_loss: 3.7519 - val_sparse_categorical_accuracy: 0.2800 - learning_rate: 5.0000e-05
# Epoch 21/40
# 4786/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.7374 - sparse_categorical_accuracy: 0.2749
# Epoch 21: val_loss improved from 3.75190 to 3.73983, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 117s 24ms/step - loss: 3.7390 - sparse_categorical_accuracy: 0.2738 - val_loss: 3.7398 - val_sparse_categorical_accuracy: 0.2814 - learning_rate: 5.0000e-05
# Epoch 22/40
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.7203 - sparse_categorical_accuracy: 0.2766
# Epoch 22: val_loss improved from 3.73983 to 3.71719, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 117s 24ms/step - loss: 3.7179 - sparse_categorical_accuracy: 0.2765 - val_loss: 3.7172 - val_sparse_categorical_accuracy: 0.2827 - learning_rate: 5.0000e-05
# Epoch 23/40
# 4786/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.6974 - sparse_categorical_accuracy: 0.2803
# Epoch 23: val_loss improved from 3.71719 to 3.70320, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 123s 26ms/step - loss: 3.6974 - sparse_categorical_accuracy: 0.2795 - val_loss: 3.7032 - val_sparse_categorical_accuracy: 0.2858 - learning_rate: 5.0000e-05
# Epoch 24/40
# 4787/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 3.6828 - sparse_categorical_accuracy: 0.2818
# Epoch 24: val_loss improved from 3.70320 to 3.69097, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 123s 26ms/step - loss: 3.6827 - sparse_categorical_accuracy: 0.2809 - val_loss: 3.6910 - val_sparse_categorical_accuracy: 0.2873 - learning_rate: 5.0000e-05
# Epoch 25/40
# 4786/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.6623 - sparse_categorical_accuracy: 0.2817
# Epoch 25: val_loss improved from 3.69097 to 3.68192, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 117s 25ms/step - loss: 3.6630 - sparse_categorical_accuracy: 0.2811 - val_loss: 3.6819 - val_sparse_categorical_accuracy: 0.2881 - learning_rate: 5.0000e-05
# Epoch 26/40
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.6432 - sparse_categorical_accuracy: 0.2856
# Epoch 26: val_loss improved from 3.68192 to 3.67395, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 118s 25ms/step - loss: 3.6451 - sparse_categorical_accuracy: 0.2849 - val_loss: 3.6740 - val_sparse_categorical_accuracy: 0.2889 - learning_rate: 5.0000e-05
# Epoch 27/40
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.6301 - sparse_categorical_accuracy: 0.2872
# Epoch 27: val_loss improved from 3.67395 to 3.66254, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 117s 24ms/step - loss: 3.6274 - sparse_categorical_accuracy: 0.2865 - val_loss: 3.6625 - val_sparse_categorical_accuracy: 0.2898 - learning_rate: 5.0000e-05
# Epoch 28/40
# 4787/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.6146 - sparse_categorical_accuracy: 0.2878
# Epoch 28: val_loss improved from 3.66254 to 3.64326, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 117s 24ms/step - loss: 3.6134 - sparse_categorical_accuracy: 0.2874 - val_loss: 3.6433 - val_sparse_categorical_accuracy: 0.2942 - learning_rate: 5.0000e-05
# Epoch 29/40
# 4786/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.5995 - sparse_categorical_accuracy: 0.2904
# Epoch 29: val_loss improved from 3.64326 to 3.63552, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 117s 24ms/step - loss: 3.5984 - sparse_categorical_accuracy: 0.2886 - val_loss: 3.6355 - val_sparse_categorical_accuracy: 0.2959 - learning_rate: 5.0000e-05
# Epoch 30/40
# 4786/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.5865 - sparse_categorical_accuracy: 0.2909
# Epoch 30: val_loss improved from 3.63552 to 3.62971, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 116s 24ms/step - loss: 3.5837 - sparse_categorical_accuracy: 0.2903 - val_loss: 3.6297 - val_sparse_categorical_accuracy: 0.2949 - learning_rate: 5.0000e-05
# Epoch 31/40
# 4786/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.5733 - sparse_categorical_accuracy: 0.2918
# Epoch 31: val_loss improved from 3.62971 to 3.61988, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 117s 24ms/step - loss: 3.5723 - sparse_categorical_accuracy: 0.2914 - val_loss: 3.6199 - val_sparse_categorical_accuracy: 0.2975 - learning_rate: 5.0000e-05
# Epoch 32/40
# 4786/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.5575 - sparse_categorical_accuracy: 0.2953
# Epoch 32: val_loss improved from 3.61988 to 3.61376, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 117s 24ms/step - loss: 3.5591 - sparse_categorical_accuracy: 0.2934 - val_loss: 3.6138 - val_sparse_categorical_accuracy: 0.2981 - learning_rate: 5.0000e-05
# Epoch 33/40
# 4787/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.5481 - sparse_categorical_accuracy: 0.2953
# Epoch 33: val_loss improved from 3.61376 to 3.59869, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 116s 24ms/step - loss: 3.5474 - sparse_categorical_accuracy: 0.2947 - val_loss: 3.5987 - val_sparse_categorical_accuracy: 0.3001 - learning_rate: 5.0000e-05
# Epoch 34/40
# 4787/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.5359 - sparse_categorical_accuracy: 0.2969
# Epoch 34: val_loss did not improve from 3.59869
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 118s 25ms/step - loss: 3.5362 - sparse_categorical_accuracy: 0.2956 - val_loss: 3.5993 - val_sparse_categorical_accuracy: 0.2995 - learning_rate: 5.0000e-05
# Epoch 35/40
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.5209 - sparse_categorical_accuracy: 0.3008
# Epoch 35: val_loss improved from 3.59869 to 3.58002, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 121s 25ms/step - loss: 3.5117 - sparse_categorical_accuracy: 0.2997 - val_loss: 3.5800 - val_sparse_categorical_accuracy: 0.3043 - learning_rate: 2.5000e-05
# Epoch 36/40
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.5068 - sparse_categorical_accuracy: 0.3022
# Epoch 36: val_loss improved from 3.58002 to 3.57273, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 119s 25ms/step - loss: 3.5054 - sparse_categorical_accuracy: 0.3003 - val_loss: 3.5727 - val_sparse_categorical_accuracy: 0.3056 - learning_rate: 2.5000e-05
# Epoch 37/40
# 4787/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.5014 - sparse_categorical_accuracy: 0.3010
# Epoch 37: val_loss improved from 3.57273 to 3.56635, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 122s 25ms/step - loss: 3.4988 - sparse_categorical_accuracy: 0.3003 - val_loss: 3.5664 - val_sparse_categorical_accuracy: 0.3060 - learning_rate: 2.5000e-05
# Epoch 38/40
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 3.4919 - sparse_categorical_accuracy: 0.3029
# Epoch 38: val_loss improved from 3.56635 to 3.56446, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 118s 25ms/step - loss: 3.4922 - sparse_categorical_accuracy: 0.3012 - val_loss: 3.5645 - val_sparse_categorical_accuracy: 0.3071 - learning_rate: 2.5000e-05
# Epoch 39/40
# 4787/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.4918 - sparse_categorical_accuracy: 0.3035
# Epoch 39: val_loss did not improve from 3.56446
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 117s 24ms/step - loss: 3.4863 - sparse_categorical_accuracy: 0.3027 - val_loss: 3.5651 - val_sparse_categorical_accuracy: 0.3065 - learning_rate: 2.5000e-05
# Epoch 40/40
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 3.4906 - sparse_categorical_accuracy: 0.3038
# Epoch 40: val_loss improved from 3.56446 to 3.54814, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_attention.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 117s 24ms/step - loss: 3.4786 - sparse_categorical_accuracy: 0.3034 - val_loss: 3.5481 - val_sparse_categorical_accuracy: 0.3090 - learning_rate: 1.2500e-05
# Restoring model weights from the end of the best epoch: 40.
# Huấn luyện xong và đã lưu history.
# Đã load best attention model từ checkpoint.

# %% [markdown]
# ## 8.3. Danh gia validation
#
# Cell nay danh gia nhanh checkpoint tot nhat tren tap validation sau khi train.

# %%
eval_results = model_lstm.evaluate(dev_dataset, steps=validation_steps, verbose=0)
print(f'Validation loss: {eval_results[0]:.4f}')
if len(eval_results) > 1:
    print(f'Validation sparse_categorical_accuracy: {eval_results[1]:.4f}')

if history_path.exists():
    with open(history_path, 'r', encoding='utf-8') as history_file:
        saved_history = json.load(history_file)
    print('Các metric đã lưu:', list(saved_history.keys()))
# Out:
# Validation loss: 3.5481
# Validation sparse_categorical_accuracy: 0.3090
# Các metric đã lưu: ['loss', 'sparse_categorical_accuracy', 'val_loss', 'val_sparse_categorical_accuracy', 'learning_rate']

# %% [markdown]
# ## 9. Test model tren mot anh
#
# Cell duoi day se:
# - load best checkpoint neu can,
# - chon 1 anh trong tap test,
# - sinh caption bang greedy decoding,
# - in caption du doan va caption tham chieu de so sanh.

# %% [markdown]
# ## 9.1. Test mot anh voi greedy decoding
#
# Cell nay sinh caption cho 1 anh test bang greedy decoding de kiem tra nhanh chat luong mo hinh.

# %%
from PIL import Image
import importlib

if importlib.util.find_spec('matplotlib') is None:
    import sys
    import subprocess
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'matplotlib'])

import matplotlib.pyplot as plt


def word_for_id(integer, tokenizer):
    """Tra ve token tu id; ho tro ca vocab bi gioi han boi num_words."""
    if integer <= 0:
        return None
    word = tokenizer.index_word.get(integer)
    if word is None:
        return None
    if tokenizer.num_words is not None and integer >= tokenizer.num_words:
        return None
    return word


def generate_caption_attention(model, tokenizer, photo_feature, max_length):
    """Sinh caption bang greedy decoding tren feature conv cua anh."""
    in_text = 'startseq'
    normalized_feature = normalize_photo_feature(photo_feature)
    if normalized_feature.ndim == 2:
        normalized_feature = normalized_feature.reshape(1, normalized_feature.shape[0], normalized_feature.shape[1])

    for _ in range(max_length):
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        sequence = pad_sequences([sequence], maxlen=max_length, padding='post')
        yhat = model.predict([normalized_feature.astype('float32'), sequence.astype('int32')], verbose=0)
        yhat_id = int(np.argmax(yhat[0]))
        word = word_for_id(yhat_id, tokenizer)
        if word is None:
            break
        in_text += ' ' + word
        if word == 'endseq':
            break

    final_tokens = [w for w in in_text.split() if w not in ('startseq', 'endseq')]
    return ' '.join(final_tokens)


def show_test_prediction(sample_image_id=None):
    """Hien thi 1 anh test, caption du doan va cac caption tham chieu."""
    global model_lstm

    if 'model_lstm' not in globals() or model_lstm is None:
        if model_path.exists():
            model_lstm = load_model(model_path)
        else:
            raise FileNotFoundError(f'Khong tim thay model tai {model_path}')

    available_ids = sorted(test_features_conv.keys())
    if not available_ids:
        raise ValueError('Tap test_features_conv dang rong, khong the test model.')

    if sample_image_id is None:
        sample_image_id = available_ids[0]
    elif sample_image_id not in test_features_conv:
        raise KeyError(f'Khong tim thay image_id {sample_image_id} trong tap test.')

    sample_image_path = os.path.join(flickr8k_images, sample_image_id + '.jpg')
    predicted_caption = generate_caption_attention(model_lstm, tokenizer, test_features_conv[sample_image_id], max_length)
    reference_captions = test_descriptions.get(sample_image_id, [])

    print(f'Test image_id: {sample_image_id}')
    print(f'Image path: {sample_image_path}')
    print(f'Predicted caption: {predicted_caption}')
    print('Reference captions:')
    for ref_caption in reference_captions[:5]:
        cleaned_ref = ref_caption.replace('startseq ', '').replace(' endseq', '')
        print(f'  - {cleaned_ref}')

    if os.path.exists(sample_image_path):
        plt.figure(figsize=(8, 6))
        plt.imshow(Image.open(sample_image_path))
        plt.axis('off')
        plt.title(predicted_caption if predicted_caption else 'Predicted caption is empty')
        plt.show()
    else:
        print('Khong mo duoc file anh de hien thi.')

    return sample_image_id, predicted_caption, reference_captions


sample_test_id, sample_prediction, sample_references = show_test_prediction()
# Out:
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Test image_id: 1056338697_4f7d7ce270
# Image path: /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/Flicker8k_Dataset/1056338697_4f7d7ce270.jpg
# Predicted caption: the woman is sitting on the street
# Reference captions:
#   - blond woman in blue shirt appears to wait for ride
#   - blond woman is on the street hailing taxi
#   - woman is signaling is to traffic as seen from behind
#   - woman with blonde hair wearing blue tube top is waving on the side of the street
#   - the woman in the blue dress is holding out her arm at oncoming traffic

# %% [markdown]
# ## 10. Test model voi beam search
#
# Cell duoi day cai thien buoc sinh caption bang cach:
# - dung beam search thay cho greedy decoding,
# - chan lap tu lien tiep qua nhieu lan,
# - so sanh caption du doan voi caption tham chieu tren anh test.

# %% [markdown]
# ## 10.1. Test mot anh voi beam search
#
# Cell nay test caption tren 1 anh bang beam search de giam lap tu va cho caption tu nhien hon.

# %%
def generate_caption_beam_search(model, tokenizer, photo_feature, max_length, beam_width=3, repetition_penalty=2):
    """Sinh caption bang beam search va giam lap tu lien tiep tren attention model."""
    normalized_feature = normalize_photo_feature(photo_feature)
    if normalized_feature.ndim == 2:
        normalized_feature = normalized_feature.reshape(1, normalized_feature.shape[0], normalized_feature.shape[1])
    normalized_feature = normalized_feature.astype('float32')

    sequences = [('startseq', 0.0)]

    for _ in range(max_length):
        all_candidates = []
        for seq_text, score in sequences:
            last_tokens = seq_text.split()
            if last_tokens[-1] == 'endseq':
                all_candidates.append((seq_text, score))
                continue

            encoded = tokenizer.texts_to_sequences([seq_text])[0]
            encoded = pad_sequences([encoded], maxlen=max_length, padding='post').astype('int32')
            yhat = model.predict([normalized_feature, encoded], verbose=0)[0]

            candidate_ids = np.argsort(yhat)[-beam_width * 4:][::-1]
            added = 0
            for token_id in candidate_ids:
                word = word_for_id(int(token_id), tokenizer)
                if not word:
                    continue

                penalty = 0.0
                if len(last_tokens) >= repetition_penalty and all(tok == word for tok in last_tokens[-repetition_penalty:]):
                    penalty = 5.0

                prob = float(yhat[token_id])
                candidate_score = score - np.log(prob + 1e-10) + penalty
                all_candidates.append((seq_text + ' ' + word, candidate_score))
                added += 1
                if added >= beam_width:
                    break

        sequences = sorted(all_candidates, key=lambda tup: tup[1])[:beam_width]
        if all(seq.split()[-1] == 'endseq' for seq, _ in sequences):
            break

    best_sequence = sequences[0][0]
    final_tokens = []
    seen_repeats = 0
    prev_word = None
    for word in best_sequence.split():
        if word in ('startseq', 'endseq'):
            continue
        if word == prev_word:
            seen_repeats += 1
            if seen_repeats >= 2:
                continue
        else:
            seen_repeats = 0
        final_tokens.append(word)
        prev_word = word
    return ' '.join(final_tokens)


def show_test_prediction_v2(sample_image_id=None, beam_width=3):
    """Test attention model voi beam search tren 1 anh test."""
    global model_lstm

    if 'model_lstm' not in globals() or model_lstm is None:
        if model_path.exists():
            model_lstm = load_model(model_path)
        else:
            raise FileNotFoundError(f'Khong tim thay model tai {model_path}')

    available_ids = sorted(test_features_conv.keys())
    if not available_ids:
        raise ValueError('Tap test_features_conv dang rong, khong the test model.')

    if sample_image_id is None:
        sample_image_id = available_ids[0]
    elif sample_image_id not in test_features_conv:
        raise KeyError(f'Khong tim thay image_id {sample_image_id} trong tap test.')

    sample_image_path = os.path.join(flickr8k_images, sample_image_id + '.jpg')
    predicted_caption = generate_caption_beam_search(
        model_lstm,
        tokenizer,
        test_features_conv[sample_image_id],
        max_length=max_length,
        beam_width=beam_width,
        repetition_penalty=repetition_penalty,
    )
    reference_captions = test_descriptions.get(sample_image_id, [])

    print(f'Test image_id: {sample_image_id}')
    print(f'Beam width: {beam_width}')
    print(f'Image path: {sample_image_path}')
    print(f'Predicted caption v2: {predicted_caption}')
    print('Reference captions:')
    for ref_caption in reference_captions[:5]:
        cleaned_ref = ref_caption.replace('startseq ', '').replace(' endseq', '')
        print(f'  - {cleaned_ref}')

    if os.path.exists(sample_image_path):
        plt.figure(figsize=(8, 6))
        plt.imshow(Image.open(sample_image_path))
        plt.axis('off')
        plt.title(predicted_caption if predicted_caption else 'Predicted caption is empty')
        plt.show()

    return sample_image_id, predicted_caption, reference_captions


repetition_penalty = 2
sample_test_id_v2, sample_prediction_v2, sample_references_v2 = show_test_prediction_v2(
    sample_image_id='1056338697_4f7d7ce270',
    beam_width=5,
)
# Out:
# Test image_id: 1056338697_4f7d7ce270
# Beam width: 5
# Image path: /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/Flicker8k_Dataset/1056338697_4f7d7ce270.jpg
# Predicted caption v2: the woman is sitting on the street
# Reference captions:
#   - blond woman in blue shirt appears to wait for ride
#   - blond woman is on the street hailing taxi
#   - woman is signaling is to traffic as seen from behind
#   - woman with blonde hair wearing blue tube top is waving on the side of the street
#   - the woman in the blue dress is holding out her arm at oncoming traffic

# %% [markdown]
# ## 10.2. Test ngau nhien 6 anh
#
# Cell nay chon ngau nhien 6 anh trong tap test, sinh caption bang beam search, in caption du doan, caption tham chieu, va hien thi anh de ban xem chat luong thuc te truoc khi tinh BLEU.

# %%
import random
from tensorflow.keras.models import load_model


def get_ready_attention_model():
    """Lay model attention hien tai, hoac tu dong load checkpoint neu can."""
    model_obj = globals().get('model_attention')
    if model_obj is not None:
        return model_obj

    checkpoint_path = MODEL_DIR / 'caption_model_attention.keras'
    if checkpoint_path.exists():
        print(f'Tu dong load best attention model tu: {checkpoint_path}')
        model_obj = load_model(checkpoint_path)
        globals()['model_attention'] = model_obj
        return model_obj

    raise NameError('Khong tim thay bien model_attention trong RAM va cung khong co checkpoint attention de load.')


def resolve_image_path(image_id):
    """Tim file anh trong thu muc dataset hien tai."""
    candidate = Path(flickr8k_images) / f'{image_id}.jpg'
    if candidate.exists():
        return candidate
    return None


def show_random_test_predictions(num_samples=6, beam_width=5, seed=42):
    """Test ngau nhien nhieu anh trong tap test voi beam search."""
    model_obj = get_ready_attention_model()
    rng = random.Random(seed)
    available_ids = sorted(test_features_conv.keys())
    if not available_ids:
        raise ValueError('Khong co anh nao trong test_features_conv de test.')

    sample_ids = rng.sample(available_ids, k=min(num_samples, len(available_ids)))
    results = []

    for image_id in sample_ids:
        predicted_caption = generate_caption_beam_search(
            model=model_obj,
            tokenizer=tokenizer,
            photo_feature=test_features_conv[image_id],
            max_length=max_length,
            beam_width=beam_width,
        )
        clean_prediction = predicted_caption.replace('startseq', '').replace('endseq', '').strip()
        references = test_descriptions.get(image_id, [])
        image_path = resolve_image_path(image_id)

        print('=' * 80)
        print(f'Test image_id: {image_id}')
        print(f'Predicted: {clean_prediction or predicted_caption}')
        print('References:')
        for ref in references:
            print(f'  - {ref.replace("startseq ", "").replace(" endseq", "")}')

        if image_path is not None and image_path.exists():
            image = load_img(image_path, target_size=(299, 299))
            plt.figure(figsize=(6, 4))
            plt.imshow(image)
            plt.axis('off')
            plt.title(clean_prediction or predicted_caption)
            plt.show()
        else:
            print('Khong tim thay file anh de hien thi.')

        results.append({
            'image_id': image_id,
            'predicted_caption': clean_prediction or predicted_caption,
            'references': [ref.replace('startseq ', '').replace(' endseq', '') for ref in references],
        })

    return results


random_test_results = show_random_test_predictions(num_samples=6, beam_width=5, seed=42)
# Out:
# ================================================================================
# Test image_id: 3339140382_2e49bc324a
# Predicted: man is jumping into the air
# References:
#   - three person sky dive team in the air performing stunt
#   - three people wearing parachutes are freefalling together through the sky
#   - three skydivers are in formation above the clouds
#   - trio of skydivers holding hands in sky
#   - two people are parachuting over white clouds
# ================================================================================
# Test image_id: 2064790732_219e52e19c
# Predicted: two girls are playing in the street
# References:
#   - boy without shirt is running in the street while several people stand behind him
#   - little boy dances with group of people behind him on city street
#   - small boy dances on the concrete surrounded by adults
#   - the little boy wearing no shirt is running by crowd of people
#   - the shirtless little boy is walking around adults
# ================================================================================
# Test image_id: 1282392036_5a0328eb86
# Predicted: group of people are playing in the grass
# References:
#   - group of people in costume at renaissance fair
#   - people in costume at renaissance fair
#   - two woman in colorful costumes look at little girl wearing brown vest
#   - two women and child are sitting by cart of arrows in front of booth at medieval fayre
#   - two women crouch near small child at medieval fair
# ================================================================================
# Test image_id: 3521374954_37371b49a4
# Predicted: little girl in blue shirt is sitting in the water
# References:
#   - baby girl and little boy are standing next to guitar and drum
#   - young laughing girl and boy are playing on big drum
#   - two little kids are beating on bongo drum
#   - two small children with blonde hair are playing drum one is smiling
#   - two young children are playing with drum
# ================================================================================
# Test image_id: 2529116152_4331dabf50
# Predicted: man in black shirt is standing in front of building
# References:
#   - darked skinned male is standing on one palm in front of yellow building
#   - man break dances
#   - man holding himself with one arm front of store
#   - young man jumps on table
#   - this black man appears to be break dancing on the pavement
# ================================================================================
# Test image_id: 2470486377_c3a39ccb7b
# Predicted: young boy in red shirt is standing in the grass
# References:
#   - boy in black shirt punches yellow punching bag while boy in blue sweatshirt holds the bag
#   - many children playing outside in the grass practicing punching
#   - some kids play outside on nice day
#   - the boy in the black sweatshirt is hitting the yellow object held by the boy in the blue sweatshirt
#   - two boys talk on field near palm trees

# %% [markdown]
# ## 11. Danh gia tong the bang BLEU score
#
# Cell duoi day tinh BLEU score tren tap test de danh gia tong the chat luong caption:
# - BLEU-1: do phu hop unigram,
# - BLEU-2: do phu hop den bigram,
# - BLEU-3 va BLEU-4: nghiem ngat hon, phan anh chat luong cum tu/cau tot hon.

# %% [markdown]
# ## 11.1. Tinh BLEU tren tap test
#
# Cell nay tinh BLEU-1 den BLEU-4 tren tap test de danh gia tong the model attention.

# %%
from nltk.translate.bleu_score import corpus_bleu, SmoothingFunction


def generate_caption_beam_search_clean(model, tokenizer, photo_feature, max_length, beam_width=5):
    """Wrapper de tao caption test on dinh cho BLEU evaluation."""
    caption = generate_caption_beam_search(
        model=model,
        tokenizer=tokenizer,
        photo_feature=photo_feature,
        max_length=max_length,
        beam_width=beam_width,
        repetition_penalty=repetition_penalty,
    )
    tokens = [token for token in caption.split() if token and token != 'unk']
    return tokens


def evaluate_bleu_scores(model, tokenizer, test_features_conv, test_descriptions, max_length, beam_width=5, limit=None):
    """Tinh BLEU-1..4 tren tap test bang beam search cho attention model."""
    actual, predicted = [], []
    image_ids = sorted(test_features_conv.keys())
    if limit is not None:
        image_ids = image_ids[:limit]

    for idx, image_id in enumerate(image_ids, start=1):
        yhat_tokens = generate_caption_beam_search_clean(
            model=model,
            tokenizer=tokenizer,
            photo_feature=test_features_conv[image_id],
            max_length=max_length,
            beam_width=beam_width,
        )
        ref_captions = []
        for ref in test_descriptions.get(image_id, []):
            tokens = [token for token in ref.split() if token not in ('startseq', 'endseq')]
            ref_captions.append(tokens)

        if ref_captions and yhat_tokens:
            actual.append(ref_captions)
            predicted.append(yhat_tokens)

        if idx % 200 == 0:
            print(f'Da danh gia {idx}/{len(image_ids)} anh test...')

    if not actual:
        raise ValueError('Khong tao duoc du lieu tham chieu/du doan hop le de tinh BLEU.')

    smoothing = SmoothingFunction().method1
    bleu1 = corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0), smoothing_function=smoothing)
    bleu2 = corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0), smoothing_function=smoothing)
    bleu3 = corpus_bleu(actual, predicted, weights=(0.34, 0.33, 0.33, 0), smoothing_function=smoothing)
    bleu4 = corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25), smoothing_function=smoothing)

    return {
        'evaluated_images': len(actual),
        'bleu_1': bleu1,
        'bleu_2': bleu2,
        'bleu_3': bleu3,
        'bleu_4': bleu4,
    }


if 'model_lstm' not in globals() or model_lstm is None:
    if model_path.exists():
        model_lstm = load_model(model_path)
    else:
        raise FileNotFoundError(f'Khong tim thay model tai {model_path}')

bleu_limit = None
bleu_results = evaluate_bleu_scores(
    model=model_lstm,
    tokenizer=tokenizer,
    test_features_conv=test_features_conv,
    test_descriptions=test_descriptions,
    max_length=max_length,
    beam_width=5,
    limit=bleu_limit,
)

print(f"So anh duoc danh gia: {bleu_results['evaluated_images']}")
print(f"BLEU-1: {bleu_results['bleu_1']:.4f}")
print(f"BLEU-2: {bleu_results['bleu_2']:.4f}")
print(f"BLEU-3: {bleu_results['bleu_3']:.4f}")
print(f"BLEU-4: {bleu_results['bleu_4']:.4f}")
# Out:
# Da danh gia 200/1000 anh test...
# Da danh gia 400/1000 anh test...
# Da danh gia 600/1000 anh test...
# Da danh gia 800/1000 anh test...
# Da danh gia 1000/1000 anh test...
# So anh duoc danh gia: 1000
# BLEU-1: 0.5285
# BLEU-2: 0.3385
# BLEU-3: 0.2097
# BLEU-4: 0.1186

# %% [markdown]
# ## 12. So sanh voi Transformer Decoder
#
# Phan duoi day them mot huong mo rong de so sanh truc tiep voi attention + LSTM hien tai:
# - giu nguyen `features_conv` tu VGG16,
# - thay decoder LSTM bang Transformer Decoder co self-attention + cross-attention,
# - train, test, va tinh BLEU rieng de so sanh cong bang.

# %% [markdown]
# ## 12.1. Xay dung Transformer Decoder
#
# Cell code duoi day dinh nghia cac thanh phan can thiet cho mo hinh Transformer Decoder:
# - `PositionalEncoding` de bo sung thong tin vi tri cho chuoi token,
# - `TransformerDecoderLayer` gom masked self-attention, cross-attention, va feed-forward,
# - `LastTokenExtractor` de lay representation cua token cuoi cung khong phai padding,
# - `define_model_transformer(...)` de ghep thanh image captioning model hoan chinh.

# %%
from tensorflow.keras.layers import LayerNormalization, MultiHeadAttention


class PositionalEncoding(tf.keras.layers.Layer):
    """Sinusoidal positional encoding cho Transformer Decoder."""
    def __init__(self, max_len, d_model, **kwargs):
        super().__init__(**kwargs)
        self.max_len = max_len
        self.d_model = d_model
        positions = np.arange(max_len)[:, np.newaxis]
        dims = np.arange(d_model)[np.newaxis, :]
        angle_rates = 1 / np.power(10000, (2 * (dims // 2)) / np.float32(d_model))
        angle_rads = positions * angle_rates
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        self.pos_encoding = tf.constant(angle_rads[np.newaxis, ...], dtype=tf.float32)

    def call(self, x):
        seq_len = tf.shape(x)[1]
        return x + self.pos_encoding[:, :seq_len, :]

    def get_config(self):
        config = super().get_config()
        config.update({'max_len': self.max_len, 'd_model': self.d_model})
        return config


class LastTokenExtractor(tf.keras.layers.Layer):
    """Lay hidden state o vi tri token cuoi cung khong phai padding."""
    def call(self, inputs):
        hidden_states, token_ids = inputs
        token_mask = tf.cast(tf.not_equal(token_ids, 0), tf.int32)
        last_index = tf.maximum(tf.reduce_sum(token_mask, axis=1) - 1, 0)
        batch_index = tf.range(tf.shape(hidden_states)[0], dtype=tf.int32)
        gather_index = tf.stack([batch_index, last_index], axis=1)
        return tf.gather_nd(hidden_states, gather_index)


class TransformerDecoderLayer(tf.keras.layers.Layer):
    """Mot block Transformer Decoder voi self-attention + cross-attention."""
    def __init__(self, d_model, num_heads, dff, dropout_rate=0.1, **kwargs):
        super().__init__(**kwargs)
        self.d_model = d_model
        self.num_heads = num_heads
        self.dff = dff
        self.dropout_rate = dropout_rate

        self.self_attn = MultiHeadAttention(num_heads=num_heads, key_dim=d_model // num_heads, name='self_attention')
        self.cross_attn = MultiHeadAttention(num_heads=num_heads, key_dim=d_model // num_heads, name='cross_attention')
        self.ffn = tf.keras.Sequential([
            Dense(dff, activation='relu'),
            Dense(d_model),
        ], name='ffn')

        self.norm1 = LayerNormalization(epsilon=1e-6, name='norm1')
        self.norm2 = LayerNormalization(epsilon=1e-6, name='norm2')
        self.norm3 = LayerNormalization(epsilon=1e-6, name='norm3')
        self.dropout1 = Dropout(dropout_rate)
        self.dropout2 = Dropout(dropout_rate)
        self.dropout3 = Dropout(dropout_rate)

    def call(self, x, encoder_output, token_ids, training=False):
        padding_mask = tf.cast(tf.not_equal(token_ids, 0), tf.int32)[:, tf.newaxis, :]
        attn1 = self.self_attn(
            query=x,
            value=x,
            key=x,
            attention_mask=padding_mask,
            use_causal_mask=True,
            training=training,
        )
        x = self.norm1(x + self.dropout1(attn1, training=training))

        attn2 = self.cross_attn(
            query=x,
            value=encoder_output,
            key=encoder_output,
            training=training,
        )
        x = self.norm2(x + self.dropout2(attn2, training=training))

        ffn_out = self.ffn(x, training=training)
        x = self.norm3(x + self.dropout3(ffn_out, training=training))
        return x

    def get_config(self):
        config = super().get_config()
        config.update({
            'd_model': self.d_model,
            'num_heads': self.num_heads,
            'dff': self.dff,
            'dropout_rate': self.dropout_rate,
        })
        return config


def transformer_custom_objects():
    return {
        'PositionalEncoding': PositionalEncoding,
        'TransformerDecoderLayer': TransformerDecoderLayer,
        'LastTokenExtractor': LastTokenExtractor,
    }


def define_model_transformer(
    vocab_size,
    max_length,
    learning_rate=5e-5,
    d_model=256,
    num_heads=4,
    dff=512,
    num_layers=1,
    dropout_rate=0.2,
    embedding_matrix=None,
    embedding_dim=100,
    embedding_trainable=False,
):
    image_input = Input(shape=(49, 512), name='image_regions_input')
    encoder_output = Dense(d_model, activation='relu', name='image_projection_transformer')(image_input)
    encoder_output = Dropout(dropout_rate, name='image_projection_dropout_transformer')(encoder_output)

    sequence_input = Input(shape=(max_length,), name='sequence_input_transformer')
    embedding_kwargs = dict(input_dim=vocab_size, output_dim=embedding_dim, mask_zero=False, name='word_embedding_transformer')
    if embedding_matrix is not None:
        embedding_kwargs['weights'] = [embedding_matrix]
        embedding_kwargs['trainable'] = embedding_trainable
    token_embedding = Embedding(**embedding_kwargs)(sequence_input)
    if embedding_dim != d_model:
        token_embedding = Dense(d_model, name='token_projection_transformer')(token_embedding)
    token_embedding = PositionalEncoding(max_len=max_length, d_model=d_model, name='positional_encoding_transformer')(token_embedding)
    token_embedding = Dropout(dropout_rate, name='token_dropout_transformer')(token_embedding)

    decoder_output = token_embedding
    for layer_index in range(num_layers):
        decoder_output = TransformerDecoderLayer(
            d_model=d_model,
            num_heads=num_heads,
            dff=dff,
            dropout_rate=dropout_rate,
            name=f'transformer_decoder_layer_{layer_index + 1}',
        )(decoder_output, encoder_output, sequence_input)

    last_token_state = LastTokenExtractor(name='last_token_state_transformer')([decoder_output, sequence_input])
    decoder_hidden = Dense(d_model, activation='relu', name='decoder_dense_transformer')(last_token_state)
    decoder_hidden = Dropout(dropout_rate, name='decoder_dropout_transformer')(decoder_hidden)
    outputs = Dense(vocab_size, activation='softmax', name='word_distribution_transformer')(decoder_hidden)

    model = Model(inputs=[image_input, sequence_input], outputs=outputs, name='caption_transformer_model')
    model.compile(
        optimizer=Adam(learning_rate=learning_rate, clipnorm=1.0),
        loss='sparse_categorical_crossentropy',
        metrics=['sparse_categorical_accuracy'],
    )
    return model


tf.keras.backend.clear_session()
model_transformer = define_model_transformer(
    vocab_size,
    max_length,
    learning_rate=5e-5,
    d_model=256,
    num_heads=4,
    dff=512,
    num_layers=1,
    dropout_rate=0.2,
    embedding_matrix=embedding_matrix,
    embedding_dim=embedding_dim,
    embedding_trainable=embedding_trainable,
)
model_transformer.summary()

# %% [markdown]
# ## 12.2. Cau hinh train Transformer
#
# Cell nay tao checkpoint rieng cho Transformer Decoder va dung lai pipeline `tf.data` streaming tu `features_conv` de train tren GPU Metal ma khong ton qua nhieu RAM.

# %%
transformer_model_path = MODEL_DIR / 'caption_model_transformer.keras'
transformer_history_path = MODEL_DIR / 'caption_model_transformer_history.json'

force_train_transformer = True
transformer_epochs = 20
transformer_batch_size = 64
transformer_learning_rate = 5e-5
transformer_d_model = 256
transformer_num_heads = 4
transformer_dff = 512
transformer_num_layers = 1
transformer_dropout_rate = 0.2

train_dataset_transformer = build_caption_dataset(
    tokenizer,
    max_length,
    train_descriptions,
    train_features_conv,
    batch_size=transformer_batch_size,
    shuffle=True,
).repeat()
dev_dataset_transformer = build_caption_dataset(
    tokenizer,
    max_length,
    dev_descriptions,
    dev_features_conv,
    batch_size=transformer_batch_size,
    shuffle=False,
).repeat()

transformer_steps_per_epoch = math.ceil(train_sample_count / transformer_batch_size)
transformer_validation_steps = math.ceil(dev_sample_count / transformer_batch_size)
(sample_inputs_transformer, sample_targets_transformer) = next(iter(train_dataset_transformer.take(1)))
(sample_images_transformer, sample_sequences_transformer) = sample_inputs_transformer

callbacks_transformer = [
    ModelCheckpoint(
        filepath=str(transformer_model_path),
        monitor='val_loss',
        save_best_only=True,
        verbose=1,
    ),
    EarlyStopping(
        monitor='val_loss',
        patience=4,
        restore_best_weights=True,
        verbose=1,
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=2,
        min_lr=1e-6,
        verbose=1,
    ),
]

print(f'Transformer model path: {transformer_model_path}')
print(f'Transformer history path: {transformer_history_path}')
print(f'force_train_transformer: {force_train_transformer}')
print(f'Epochs: {transformer_epochs}, batch_size: {transformer_batch_size}, learning_rate: {transformer_learning_rate}')
print(f'd_model: {transformer_d_model}, num_heads: {transformer_num_heads}, dff: {transformer_dff}, num_layers: {transformer_num_layers}')
print(f'GloVe active: {embedding_matrix is not None}, embedding_trainable: {embedding_trainable}')
print(f'Train samples: {train_sample_count:,}, steps/epoch: {transformer_steps_per_epoch}')
print(f'Dev samples: {dev_sample_count:,}, validation_steps: {transformer_validation_steps}')
print(f'Sample image batch: {sample_images_transformer.shape}, dtype={sample_images_transformer.dtype}')
print(f'Sample sequence batch: {sample_sequences_transformer.shape}, dtype={sample_sequences_transformer.dtype}')
print(f'Sample target batch: {sample_targets_transformer.shape}, dtype={sample_targets_transformer.dtype}')
print('Transformer da duoc chinh de on dinh hon: lr=5e-5, num_layers=1, dropout=0.2, clipnorm=1.0')

# %% [markdown]
# ## 12.3. Train Transformer Decoder
#
# Cell nay huan luyen Transformer Decoder hoac load checkpoint tot nhat neu da ton tai, de ban co the so sanh truc tiep voi attention model.

# %%
history_transformer = None

if transformer_model_path.exists() and not force_train_transformer:
    print('Da tim thay model Transformer da train truoc do, se load de evaluate/inference.')
    model_transformer = load_model(transformer_model_path, custom_objects=transformer_custom_objects())
else:
    tf.keras.backend.clear_session()
    model_transformer = define_model_transformer(
        vocab_size,
        max_length,
        learning_rate=transformer_learning_rate,
        d_model=transformer_d_model,
        num_heads=transformer_num_heads,
        dff=transformer_dff,
        num_layers=transformer_num_layers,
        dropout_rate=transformer_dropout_rate,
        embedding_matrix=embedding_matrix,
        embedding_dim=embedding_dim,
        embedding_trainable=embedding_trainable,
    )
    if transformer_model_path.exists() and force_train_transformer:
        print('Da co checkpoint Transformer cu, nhung force_train_transformer=True nen se train lai.')
    else:
        print('Chua co model Transformer da train, bat dau huan luyen...')
    transformer_gpu_devices = tf.config.list_physical_devices('GPU')
    print(f'Transformer physical GPUs truoc khi fit: {transformer_gpu_devices}')
    print('Transformer dang train bang GPU.' if transformer_gpu_devices else 'Transformer dang train bang CPU.')
    history_transformer = model_transformer.fit(
        train_dataset_transformer,
        validation_data=dev_dataset_transformer,
        epochs=transformer_epochs,
        steps_per_epoch=transformer_steps_per_epoch,
        validation_steps=transformer_validation_steps,
        callbacks=callbacks_transformer,
        verbose=1,
    )
    with open(transformer_history_path, 'w', encoding='utf-8') as history_file:
        json.dump(history_transformer.history, history_file, ensure_ascii=False, indent=2)
    print('Huấn luyện Transformer xong và đã lưu history.')

if transformer_model_path.exists():
    model_transformer = load_model(transformer_model_path, custom_objects=transformer_custom_objects())
    print('Da load best Transformer model tu checkpoint.')
# Out:
# Da co checkpoint Transformer cu, nhung force_train_transformer=True nen se train lai.
# Transformer physical GPUs truoc khi fit: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Transformer dang train bang GPU.
# Epoch 1/20
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - loss: 5.0529 - sparse_categorical_accuracy: 0.1979
# Epoch 1: val_loss improved from None to 4.09611, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_transformer.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 634s 131ms/step - loss: 4.5594 - sparse_categorical_accuracy: 0.2298 - val_loss: 4.0961 - val_sparse_categorical_accuracy: 0.2594 - learning_rate: 1.0000e-04
# Epoch 2/20
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 3.9968 - sparse_categorical_accuracy: 0.2651
# Epoch 2: val_loss improved from 4.09611 to 3.85660, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_transformer.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 603s 126ms/step - loss: 3.9556 - sparse_categorical_accuracy: 0.2677 - val_loss: 3.8566 - val_sparse_categorical_accuracy: 0.2739 - learning_rate: 1.0000e-04
# Epoch 3/20
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 3.8140 - sparse_categorical_accuracy: 0.2787
# Epoch 3: val_loss improved from 3.85660 to 3.82424, saving model to /Applications/Python_AI/Neural_Image_Caption_Generation/workspace/models/caption_model_transformer.keras
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 601s 126ms/step - loss: 3.8062 - sparse_categorical_accuracy: 0.2778 - val_loss: 3.8242 - val_sparse_categorical_accuracy: 0.2741 - learning_rate: 1.0000e-04
# Epoch 4/20
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 4.4453 - sparse_categorical_accuracy: 0.2467
# Epoch 4: val_loss did not improve from 3.82424
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 603s 126ms/step - loss: 6.3158 - sparse_categorical_accuracy: 0.1865 - val_loss: 7.3115 - val_sparse_categorical_accuracy: 0.1490 - learning_rate: 1.0000e-04
# Epoch 5/20
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 14.3137 - sparse_categorical_accuracy: 0.0678
# Epoch 5: val_loss did not improve from 3.82424
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 598s 125ms/step - loss: 15.7884 - sparse_categorical_accuracy: 0.0649 - val_loss: 9.3630 - val_sparse_categorical_accuracy: 0.1463 - learning_rate: 5.0000e-05
# Epoch 6/20
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 17.0985 - sparse_categorical_accuracy: 0.0593
# Epoch 6: val_loss did not improve from 3.82424
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 599s 125ms/step - loss: 18.9122 - sparse_categorical_accuracy: 0.0488 - val_loss: 12.0572 - val_sparse_categorical_accuracy: 0.1093 - learning_rate: 2.5000e-05
# Epoch 7/20
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 20.7856 - sparse_categorical_accuracy: 0.0340
# Epoch 7: val_loss did not improve from 3.82424
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 629s 131ms/step - loss: 21.2401 - sparse_categorical_accuracy: 0.0326 - val_loss: 12.7417 - val_sparse_categorical_accuracy: 0.1086 - learning_rate: 1.2500e-05
# Epoch 8/20
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 21.2628 - sparse_categorical_accuracy: 0.0364
# Epoch 8: val_loss did not improve from 3.82424
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 4788/4788 ━━━━━━━━━━━━━━━━━━━━ 602s 126ms/step - loss: 21.9817 - sparse_categorical_accuracy: 0.0381 - val_loss: 13.9147 - val_sparse_categorical_accuracy: 0.1260 - learning_rate: 6.2500e-06
# Epoch 8: early stopping
# Restoring model weights from the end of the best epoch: 3.
# Huấn luyện Transformer xong và đã lưu history.
# /opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/layers/layer.py:421: UserWarning: `build()` was called on layer 'transformer_decoder_layer_1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/layers/layer.py:421: UserWarning: `build()` was called on layer 'transformer_decoder_layer_2', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Da load best Transformer model tu checkpoint.

# %% [markdown]
# ## 12.4. Danh gia Transformer tren validation
#
# Cell nay danh gia nhanh checkpoint tot nhat cua Transformer tren tap validation de ban so sanh voi attention model theo cung bo metric `val_loss` va `val_sparse_categorical_accuracy`.

# %%
eval_results_transformer = model_transformer.evaluate(
    dev_dataset_transformer,
    steps=transformer_validation_steps,
    verbose=0,
)
print(f'Transformer validation loss: {eval_results_transformer[0]:.4f}')
if len(eval_results_transformer) > 1:
    print(f'Transformer validation sparse_categorical_accuracy: {eval_results_transformer[1]:.4f}')

if transformer_history_path.exists():
    with open(transformer_history_path, 'r', encoding='utf-8') as history_file:
        saved_history_transformer = json.load(history_file)
    print('Transformer metrics da luu:', list(saved_history_transformer.keys()))
# Out:
# Transformer validation loss: 3.8242
# Transformer validation sparse_categorical_accuracy: 0.2741
# Transformer metrics da luu: ['loss', 'sparse_categorical_accuracy', 'val_loss', 'val_sparse_categorical_accuracy', 'learning_rate']

# %% [markdown]
# ## 12.5. Test Transformer tren 1 anh
#
# Cell nay sinh caption cho mot anh test bang beam search, de ban so sanh nhanh chat luong cau sinh ra giua Transformer va attention model.

# %%
import os
import tensorflow as tf
def word_for_id_transformer(integer, tokenizer):
    if integer <= 0:
        return None
    word = tokenizer.index_word.get(integer)
    if word is None:
        return None
    if tokenizer.num_words is not None and integer >= tokenizer.num_words:
        return None
    return word


def generate_caption_beam_search_transformer(model, tokenizer, photo_feature, max_length, beam_width=5, repetition_penalty=2):
    normalized_feature = normalize_photo_feature(photo_feature)
    if normalized_feature.ndim == 2:
        normalized_feature = normalized_feature.reshape(1, normalized_feature.shape[0], normalized_feature.shape[1])
    normalized_feature = normalized_feature.astype('float32')

    sequences = [('startseq', 0.0)]
    for _ in range(max_length):
        all_candidates = []
        for seq_text, score in sequences:
            last_tokens = seq_text.split()
            if last_tokens[-1] == 'endseq':
                all_candidates.append((seq_text, score))
                continue

            encoded = tokenizer.texts_to_sequences([seq_text])[0]
            encoded = pad_sequences([encoded], maxlen=max_length, padding='post').astype('int32')
            yhat = model.predict([normalized_feature, encoded], verbose=0)[0]

            candidate_ids = np.argsort(yhat)[-beam_width * 4:][::-1]
            added = 0
            for token_id in candidate_ids:
                word = word_for_id_transformer(int(token_id), tokenizer)
                if not word:
                    continue

                penalty = 0.0
                if len(last_tokens) >= repetition_penalty and all(tok == word for tok in last_tokens[-repetition_penalty:]):
                    penalty = 5.0

                prob = float(yhat[token_id])
                candidate_score = score - np.log(prob + 1e-10) + penalty
                all_candidates.append((seq_text + ' ' + word, candidate_score))
                added += 1
                if added >= beam_width:
                    break

        sequences = sorted(all_candidates, key=lambda tup: tup[1])[:beam_width]
        if all(seq.split()[-1] == 'endseq' for seq, _ in sequences):
            break

    best_sequence = sequences[0][0]
    final_tokens = []
    seen_repeats = 0
    prev_word = None
    for word in best_sequence.split():
        if word in ('startseq', 'endseq'):
            continue
        if word == prev_word:
            seen_repeats += 1
            if seen_repeats >= 2:
                continue
        else:
            seen_repeats = 0
        final_tokens.append(word)
        prev_word = word
    return ' '.join(final_tokens)


def show_transformer_prediction(sample_image_id='1056338697_4f7d7ce270', beam_width=5):
    global model_transformer

    if 'model_transformer' not in globals() or model_transformer is None:
        if transformer_model_path.exists():
            model_transformer = load_model(transformer_model_path, custom_objects=transformer_custom_objects())
        else:
            raise FileNotFoundError(f'Khong tim thay Transformer model tai {transformer_model_path}')

    if sample_image_id not in test_features_conv:
        raise KeyError(f'Khong tim thay image_id {sample_image_id} trong test_features_conv')

    image_path = os.path.join(flickr8k_images, sample_image_id + '.jpg')
    predicted_caption = generate_caption_beam_search_transformer(
        model_transformer,
        tokenizer,
        test_features_conv[sample_image_id],
        max_length=max_length,
        beam_width=beam_width,
        repetition_penalty=2,
    )
    reference_captions = test_descriptions.get(sample_image_id, [])

    print(f'Test image_id: {sample_image_id}')
    print(f'Beam width: {beam_width}')
    print(f'Image path: {image_path}')
    print(f'Transformer predicted caption: {predicted_caption}')
    print('Reference captions:')
    for ref_caption in reference_captions[:5]:
        cleaned_ref = ref_caption.replace('startseq ', '').replace(' endseq', '')
        print(f'  - {cleaned_ref}')

    if os.path.exists(image_path):
        plt.figure(figsize=(8, 6))
        plt.imshow(Image.open(image_path))
        plt.axis('off')
        plt.title(predicted_caption if predicted_caption else 'Transformer predicted caption is empty')
        plt.show()

    return sample_image_id, predicted_caption, reference_captions


sample_transformer_test_id, sample_transformer_prediction, sample_transformer_references = show_transformer_prediction()
# Out:
# 2026-03-18 18:20:50.178777: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: CANCELLED: RecvAsync is cancelled.
# 	 [[{{node caption_transformer_model_1/transformer_decoder_layer_1_1/cross_attention_1/Softmax/_42}}]] [type.googleapis.com/tensorflow.DerivedStatus='']
# 2026-03-18 18:20:50.178795: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 2981703976346132938
# 2026-03-18 18:20:50.178800: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 8020900831364367062
# 2026-03-18 18:20:50.178804: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 3171957586822595098
# 2026-03-18 18:20:50.178809: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 12387497431973447392
# 2026-03-18 18:20:50.178813: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 15097917620725687982
# 2026-03-18 18:20:50.178815: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 11398541570979433276
# 2026-03-18 18:20:50.178819: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 13289619702833811594
# 2026-03-18 18:20:50.178822: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 7831179954010345860
# 2026-03-18 18:20:50.178825: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 14702327441230754182
# 2026-03-18 18:20:50.178829: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 2139133912124880338
# 2026-03-18 18:20:50.178832: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 12177028952735241814
# 2026-03-18 18:20:50.178835: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 3974740896341694816
# 2026-03-18 18:20:50.178838: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 6782410149288115836
# 2026-03-18 18:20:50.178841: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 730450122033750367
# 2026-03-18 18:20:50.178843: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous send item cancelled. Key hash: 11821295563013050953
# 2026-03-18 18:20:50.178847: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 10881934438026453993
# 2026-03-18 18:20:50.178850: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 17854928524592166649
# 2026-03-18 18:20:50.178853: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 12228558859595609819
# 2026-03-18 18:20:50.178855: I tensorflow/core/framework/local_rendezvous.cc:426] Local rendezvous send item cancelled. Key hash: 5134344889291483733
# 2026-03-18 18:20:50.178858: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 2497373379431168649
# 2026-03-18 18:20:50.178862: I tensorflow/core/framework/local_rendezvous.cc:422] Local rendezvous recv item cancelled. Key hash: 16595351838863084637
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[40], line 115
#     110         plt.show()
#     112     return sample_image_id, predicted_caption, reference_captions
# --> 115 sample_transformer_test_id, sample_transformer_prediction, sample_transformer_references = show_transformer_prediction()
#
# Cell In[40], line 86, in show_transformer_prediction(sample_image_id, beam_width)
#      83     raise KeyError(f'Khong tim thay image_id {sample_image_id} trong test_features_conv')
#      85 image_path = os.path.join(flickr8k_images, sample_image_id + '.jpg')
# ---> 86 predicted_caption = generate_caption_beam_search_transformer(
#      87     model_transformer,
#      88     tokenizer,
#      89     test_features_conv[sample_image_id],
#      90     max_length=max_length,
#      91     beam_width=beam_width,
#      92     repetition_penalty=2,
#      93 )
#      94 reference_captions = test_descriptions.get(sample_image_id, [])
#      96 print(f'Test image_id: {sample_image_id}')
#
# Cell In[40], line 31, in generate_caption_beam_search_transformer(model, tokenizer, photo_feature, max_length, beam_width, repetition_penalty)
#      29 encoded = tokenizer.texts_to_sequences([seq_text])[0]
#      30 encoded = pad_sequences([encoded], maxlen=max_length, padding='post').astype('int32')
# ---> 31 yhat = model.predict([normalized_feature, encoded], verbose=0)[0]
#      33 candidate_ids = np.argsort(yhat)[-beam_width * 4:][::-1]
#      34 added = 0
#
# File /opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File /opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# NotFoundError: Graph execution error:
#
# Detected at node caption_transformer_model_1/transformer_decoder_layer_2_1/self_attention_1/LogicalAnd defined at (most recent call last):
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 758, in start
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 211, in start
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/ipykernel/utils.py", line 71, in preserve_context
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 621, in shell_main
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 478, in dispatch_shell
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 372, in execute_request
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 834, in execute_request
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 464, in do_execute
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#
#   File "/var/folders/g0/hkl2gd9d4n18d4jzk0xkz0hm0000gn/T/ipykernel_83902/2028043271.py", line 113, in <module>
#
#   File "/var/folders/g0/hkl2gd9d4n18d4jzk0xkz0hm0000gn/T/ipykernel_83902/2028043271.py", line 84, in show_transformer_prediction
#
#   File "/var/folders/g0/hkl2gd9d4n18d4jzk0xkz0hm0000gn/T/ipykernel_83902/2028043271.py", line 29, in generate_caption_beam_search_transformer
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 588, in predict
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 282, in one_step_on_data_distributed
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 125, in wrapper
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 271, in one_step_on_data
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py", line 110, in predict_step
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/layers/layer.py", line 941, in __call__
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/ops/operation.py", line 59, in __call__
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 156, in error_handler
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/models/functional.py", line 183, in call
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/ops/function.py", line 206, in _run_through_graph
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/models/functional.py", line 644, in call
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/layers/layer.py", line 941, in __call__
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/ops/operation.py", line 59, in __call__
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 156, in error_handler
#
#   File "/var/folders/g0/hkl2gd9d4n18d4jzk0xkz0hm0000gn/T/ipykernel_83902/2325937570.py", line 64, in call
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/layers/layer.py", line 941, in __call__
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 117, in error_handler
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/ops/operation.py", line 59, in __call__
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 156, in error_handler
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/layers/attention/multi_head_attention.py", line 560, in call
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/layers/attention/multi_head_attention.py", line 476, in _compute_attention
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/ops/nn.py", line 2750, in dot_product_attention
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/backend/tensorflow/nn.py", line 1077, in dot_product_attention
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/backend/tensorflow/nn.py", line 1028, in _dot_product_attention_xla
#
#   File "/opt/anaconda3/envs/tf-metal/lib/python3.10/site-packages/keras/src/backend/tensorflow/nn.py", line 1004, in _apply_masks
#
# No registered 'BroadcastTo' OpKernel for 'GPU' devices compatible with node {{node caption_transformer_model_1/transformer_decoder_layer_2_1/self_attention_1/LogicalAnd}}
# 	 (OpKernel was found, but attributes didn't match) Requested Attributes: T=DT_BOOL, Tidx=DT_INT32, _XlaHasReferenceVars=false, _device="/job:localhost/replica:0/task:0/device:GPU:0"
# 	.  Registered:  device='XLA_CPU_JIT'; Tidx in [DT_INT32, DT_INT64]; T in [DT_FLOAT, DT_DOUBLE, DT_INT32, DT_UINT8, DT_INT16, DT_INT8, DT_COMPLEX64, DT_INT64, DT_BOOL, DT_QINT8, DT_QUINT8, DT_QINT32, DT_BFLOAT16, DT_UINT16, DT_COMPLEX128, DT_HALF, DT_UINT32, DT_UINT64, DT_FLOAT8_E5M2, DT_FLOAT8_E4M3FN, DT_INT4, DT_UINT4]
#   device='GPU'; T in [DT_FLOAT]
#   device='GPU'; T in [DT_HALF]
#   device='GPU'; T in [DT_BFLOAT16]
#   device='DEFAULT'; T in [DT_INT32]
#   device='CPU'; T in [DT_UINT64]
#   device='CPU'; T in [DT_INT64]
#   device='CPU'; T in [DT_UINT32]
#   device='CPU'; T in [DT_UINT16]
#   device='CPU'; T in [DT_INT16]
#   device='CPU'; T in [DT_UINT8]
#   device='CPU'; T in [DT_INT8]
#   device='CPU'; T in [DT_INT32]
#   device='CPU'; T in [DT_HALF]
#   device='CPU'; T in [DT_BFLOAT16]
#   device='CPU'; T in [DT_FLOAT]
#   device='CPU'; T in [DT_DOUBLE]
#   device='CPU'; T in [DT_COMPLEX64]
#   device='CPU'; T in [DT_COMPLEX128]
#   device='CPU'; T in [DT_BOOL]
#   device='CPU'; T in [DT_STRING]
#   device='CPU'; T in [DT_RESOURCE]
#   device='CPU'; T in [DT_VARIANT]
#   device='CPU'; T in [DT_FLOAT8_E5M2]
#   device='CPU'; T in [DT_FLOAT8_E4M3FN]
#
# 	 [[caption_transformer_model_1/transformer_decoder_layer_2_1/self_attention_1/LogicalAnd]] [Op:__inference_one_step_on_data_distributed_3891046]

# %% [markdown]
# ## 12.6. Tinh BLEU cho Transformer
#
# Cell nay tinh BLEU-1 den BLEU-4 tren tap test cho Transformer Decoder, de ban so sanh cong bang voi attention model.

# %%
transformer_bleu_limit = None
transformer_bleu_results = {}
selected_transformer_ids = sorted(test_features_conv.keys())[:transformer_bleu_limit] if transformer_bleu_limit else sorted(test_features_conv.keys())

references_transformer = []
hypotheses_transformer = []
for idx, image_id in enumerate(selected_transformer_ids, start=1):
    predicted_caption = generate_caption_beam_search_transformer(
        model_transformer,
        tokenizer,
        test_features_conv[image_id],
        max_length=max_length,
        beam_width=5,
        repetition_penalty=2,
    )
    transformer_bleu_results[image_id] = predicted_caption

    refs = [[word for word in cap.split() if word not in ['startseq', 'endseq']] for cap in test_descriptions[image_id]]
    hyp = predicted_caption.split()
    references_transformer.append(refs)
    hypotheses_transformer.append(hyp)

    if idx % 200 == 0 or idx == len(selected_transformer_ids):
        print(f'Da danh gia {idx}/{len(selected_transformer_ids)} anh test cho Transformer...')

bleu1_transformer = corpus_bleu(references_transformer, hypotheses_transformer, weights=(1, 0, 0, 0))
bleu2_transformer = corpus_bleu(references_transformer, hypotheses_transformer, weights=(0.5, 0.5, 0, 0))
bleu3_transformer = corpus_bleu(references_transformer, hypotheses_transformer, weights=(0.33, 0.33, 0.33, 0))
bleu4_transformer = corpus_bleu(references_transformer, hypotheses_transformer, weights=(0.25, 0.25, 0.25, 0.25))

print(f'So anh Transformer duoc danh gia: {len(selected_transformer_ids)}')
print(f'Transformer BLEU-1: {bleu1_transformer:.4f}')
print(f'Transformer BLEU-2: {bleu2_transformer:.4f}')
print(f'Transformer BLEU-3: {bleu3_transformer:.4f}')
print(f'Transformer BLEU-4: {bleu4_transformer:.4f}')
